# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %%
import numpy as np

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

len(twits['data'])
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')


def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    
    # Lowercase the twit message
    text = message.lower()
    
    # Replace URLs with a space in the message
    text = re.sub(r'https?://[^\s]+', ' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'\$[a-zA-Z0-9]*', ' ', text)
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'@[a-zA-Z0-9]*', ' ', text)

    # Replace everything not a letter with a space
    text = re.sub(r'[^a-z]', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = text.split()

    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [wnl.lemmatize(token) for token in tokens if len(token)>1]
    
    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
messages[0].lower()
# Out:
# '$fitb great buy at 26.00...ill wait'

# %%
tokenized = [preprocess(message) for message in messages]

# %%
tokenized
# Out:
# [['great', 'buy', 'at', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['heard',
#   'there',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'on',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why',
#   'the',
#   'drop',
#   'warren',
#   'buffet',
#   'taking',
#   'out',
#   'his',
#   'position'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['ok',
#   'good',
#   'we',
#   're',
#   'not',
#   'dropping',
#   'in',
#   'price',
#   'over',
#   'the',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'to', 'get', 'back', 'to', 'above'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'in',
#   'month',
#   'back',
#   'to',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'is',
#   'the',
#   'odds'],
#  ['strong', 'buy'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['price',
#   'squeezing',
#   'perfect',
#   'place',
#   'for',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'the',
#   'supporting',
#   'trend'],
#  ['start',
#   'of',
#   'new',
#   'on',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'of',
#   'various',
#   'sector'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['catalyst',
#   'continuing',
#   'this',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earnings',
#   'test',
#   'break',
#   'of',
#   'soon'],
#  ['ha', 'moved', 'on', 'check', 'out', 'the', 'movement', 'and', 'peer', 'at'],
#  ['staanalystalert',
#   'for',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['think',
#   'it',
#   'is',
#   'too',
#   'early',
#   'to',
#   'tell',
#   'what',
#   'going',
#   'to',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'the',
#   'current',
#   'news',
#   'about',
#   'raisinf',
#   'output',
#   'there',
#   'is',
#   'still',
#   'so',
#   'many'],
#  ['ha',
#   'current',
#   'ratio',
#   'of',
#   'so',
#   'it',
#   'is',
#   'financially',
#   'healthy',
#   'and',
#   'ha',
#   'no',
#   'problem',
#   'in',
#   'meeting',
#   'it',
#   'obligation'],
#  ['bullish', 'stock', 'to', 'watch', 'setup', 'timeframes', 'blog', 'by'],
#  ['just', 'short', 'it'],
#  ['high', 'alert', 'for', 'next', 'week', 'gt', 'breakdown'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['miss', 'these', 'day'],
#  ['if',
#   'break',
#   'and',
#   'confirms',
#   'next',
#   'week',
#   'you',
#   'will',
#   'see',
#   'violent',
#   'move',
#   'downward',
#   'to',
#   'my',
#   'buy',
#   'price'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['breakout',
#   'base',
#   'gap',
#   'and',
#   'day',
#   'ma',
#   'gap',
#   'gap',
#   'gap',
#   'and',
#   'day',
#   'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'to',
#   'watch',
#   'quot'],
#  ['when',
#   'wa',
#   'kid',
#   'my',
#   'froend',
#   'told',
#   'me',
#   'the',
#   'moon',
#   'wa',
#   'made',
#   'out',
#   'of',
#   'cheese'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'wa',
#   'on',
#   'and',
#   'day',
#   'rank',
#   'wa',
#   'th',
#   'percentile'],
#  ['thank',
#   'you',
#   'don',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'tell',
#   'or',
#   'to',
#   'do',
#   'well',
#   'for',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'the',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   'remember',
#   'single',
#   'movie',
#   'he',
#   'watched',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothes'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'hold'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['although',
#   'the',
#   'market',
#   'is',
#   'up',
#   'is',
#   'doing',
#   'even',
#   'better',
#   'it',
#   'ha',
#   'advanced',
#   'a',
#   'of',
#   'more',
#   'info',
#   'peer',
#   'at'],
#  ['july',
#   'will',
#   'be',
#   'the',
#   'most',
#   'bullish',
#   'day',
#   'of',
#   'the',
#   'year',
#   'for',
#   'stock'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['third', 'design', 'win', 'the', 'timing', 'match', 'it', 'probably', 'arm'],
#  ['alcohol',
#   'stock',
#   'tobacco',
#   'stock',
#   'and',
#   'firearm',
#   'stock',
#   'to',
#   'buy'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'spoke',
#   'to',
#   'king',
#   'salman',
#   'of',
#   'saudi',
#   'arabia',
#   'and',
#   'explained',
#   'to',
#   'him',
#   'that',
#   'because',
#   'of',
#   'the',
#   'turmoil',
#   'amp'],
#  ['today', 'insight', 'on'],
#  ['intc',
#   'mama',
#   'said',
#   'get',
#   'ice',
#   'cream',
#   'if',
#   'finish',
#   'my',
#   'due',
#   'dil'],
#  ['just',
#   'noticed',
#   'they',
#   'have',
#   'the',
#   'last',
#   'jedi',
#   'on',
#   'stream',
#   'love',
#   'this',
#   'stock'],
#  ['here', 'you', 'go', 'will', 'just', 'leave', 'this', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   'ema',
#   'held',
#   'above',
#   'ema',
#   'and',
#   'stochastics',
#   'turning',
#   'healthy',
#   'a',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'cheap'],
#  ['saber',
#   'capital',
#   'presentation',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'and',
#   'google'],
#  ['how', 'expect', 'the', 'earnings'],
#  ['is',
#   'one',
#   'of',
#   'the',
#   'better',
#   'performing',
#   'stock',
#   'in',
#   'the',
#   'crude',
#   'petroleum',
#   'and',
#   'natural',
#   'gas',
#   'industry'],
#  ['pu',
#   'it',
#   'simply',
#   'havent',
#   'lost',
#   'on',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mf',
#   'are',
#   'well',
#   'educated',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'of',
#   'global',
#   'manufacturing',
#   'at',
#   'pfizer',
#   'is',
#   'an',
#   'independent',
#   'director',
#   'at',
#   'nat',
#   'ricciardi'],
#  ['may', 'be', 'the', 'safest', 'stock', 'own'],
#  ['special',
#   'limited',
#   'offer',
#   'june',
#   'th',
#   'june',
#   'th',
#   'tradenet',
#   'is',
#   'offering',
#   'discount',
#   'on',
#   'intro',
#   'program'],
#  ['below', 'buy', 'put', 'on', 'financials'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['low',
#   'peg',
#   'ratio',
#   'which',
#   'compensates',
#   'the',
#   'pe',
#   'for',
#   'growth',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'equity'],
#  ['coming'],
#  ['seems', 'is', 'the', 'support', 'next', 'if', 'under', 'is', 'likely'],
#  ['ha', 'moved', 'on', 'check', 'out', 'the', 'movement', 'and', 'peer', 'at'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fucking',
#   'nothing',
#   'this',
#   'is',
#   'macau',
#   'not',
#   'fucking',
#   'usa'],
#  ['take',
#   'this',
#   'let',
#   'me',
#   'know',
#   'where',
#   'are',
#   'we',
#   'right',
#   'now',
#   'lol'],
#  ['the',
#   'chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   'll',
#   'buy',
#   'when',
#   'this',
#   'is',
#   'at'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['previously',
#   'there',
#   'wa',
#   'mo',
#   'run',
#   'up',
#   'followed',
#   'by',
#   'drop',
#   'we',
#   'are',
#   'at',
#   'the',
#   'end',
#   'of',
#   'month',
#   'of',
#   'another',
#   'runup',
#   'and',
#   'have',
#   'dropped',
#   'about'],
#  ['smart', 'money', 'betting', 'on', 'call', 'deal', 'update'],
#  ['although',
#   'the',
#   'technical',
#   'rating',
#   'is',
#   'bad',
#   'doe',
#   'present',
#   'nice',
#   'setup',
#   'opportunity'],
#  ['will',
#   'completely',
#   'scale',
#   'out',
#   'in',
#   'time',
#   'to',
#   'gobble',
#   'up',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['them', 'are', 'iddy', 'bitty', 'kiddy', 'hand'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['then',
#   'awesome',
#   'it',
#   'is',
#   'now',
#   'be',
#   'concerned',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'for',
#   'u',
#   'capital',
#   'advisor',
#   'upgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'are',
#   'dreaming',
#   'of',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'updated',
#   'hormel',
#   'food',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today', 'insight', 'on'],
#  ['just',
#   'updated',
#   'intel',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'are',
#   'both',
#   'positive',
#   'this',
#   'is',
#   'looking',
#   'good'],
#  ['they', 'so', 'mad', 'at', 'me', 'still'],
#  ['back', 'to', 'by', 'july'],
#  ['report', 'and', 'block', 'this', 'person', 'spam'],
#  ['should', 'open', 'at', 'on', 'monday'],
#  ['my',
#   'projection',
#   'for',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'is',
#   'next',
#   'week',
#   'thats',
#   'why',
#   'prefer',
#   'to',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'turd'],
#  ['percent', 'short', 'volume', 'for', 'wa', 'on'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['looking',
#   'for',
#   'marriage',
#   'have',
#   'in',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'in',
#   'stock',
#   'dm'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['to',
#   'that',
#   'bear',
#   'that',
#   'won',
#   'stop',
#   'posting',
#   'holding',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'and',
#   'good',
#   'luck',
#   'lol'],
#  ['the',
#   'chase',
#   'continues',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announces',
#   'the',
#   'rd',
#   'win'],
#  ['the',
#   'price',
#   'earnings',
#   'ratio',
#   'is',
#   'which',
#   'indicates',
#   'rather',
#   'cheap',
#   'valuation',
#   'of'],
#  ['permamently',
#   'turned',
#   'me',
#   'off',
#   'of',
#   'option',
#   'trading',
#   'and',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'to',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk',
#   'it'],
#  ['is',
#   'down',
#   'almost',
#   'pct',
#   'from',
#   'it',
#   'week',
#   'high',
#   'it',
#   'about',
#   'time',
#   'for',
#   'buyback',
#   'got',
#   'more',
#   'share',
#   'in',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  [],
#  ['dumped',
#   'call',
#   'friday',
#   'at',
#   'open',
#   'that',
#   'wa',
#   'obv',
#   'but',
#   'jeez',
#   'bit',
#   'over',
#   'done',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'heikin',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'a',
#   'well',
#   'will',
#   'be',
#   'looking',
#   'for',
#   'confirmation'],
#  ['liking', 'this'],
#  ['look',
#   'for',
#   'wife',
#   'got',
#   'about',
#   'tree',
#   'fiddy',
#   'in',
#   'stock',
#   'and',
#   'it',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'ha',
#   'got',
#   'lot',
#   'of',
#   'coin',
#   'may',
#   'spend',
#   'on',
#   'candy',
#   'no',
#   'dm',
#   'though'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['just',
#   'updated',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology'],
#  ['bearish', 'investor', 'aren', 'happy', 'today', 'for', 'a', 'of'],
#  ['staanalystalert',
#   'for',
#   'royal',
#   'bank',
#   'of',
#   'canada',
#   'reiterates',
#   'with',
#   'rating',
#   'of',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['kid', 'never', 'been', 'wrong', 'he', 'miracle'],
#  ['what', 'is', 'period', 'bollinger', 'band', 'mean'],
#  ['you',
#   'dare',
#   'say',
#   'didn',
#   'know',
#   'you',
#   'are',
#   'a',
#   'guilty',
#   'a',
#   'fudge'],
#  ['today', 'insight', 'on'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'and',
#   'the',
#   'page',
#   'is',
#   'broken',
#   'giving',
#   'endless',
#   'buffering',
#   'icon',
#   'give',
#   'up',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'video',
#   'highlight',
#   'growing',
#   'movement',
#   'of',
#   'democrat',
#   'leaving',
#   'the',
#   'party',
#   'the',
#   'epoch',
#   'time'],
#  ['staanalystalert',
#   'for',
#   'robert',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['too', 'much', 'weed', 'and', 'other', 'drug', 'guess'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'described',
#   'a',
#   'very',
#   'reasonable'],
#  ['the',
#   'reason',
#   'nike',
#   'is',
#   'winning',
#   'is',
#   'because',
#   'of',
#   'their',
#   'click',
#   'booking',
#   'app',
#   'it',
#   'better',
#   'than',
#   'native',
#   'seamless',
#   'lovalized',
#   'transactable',
#   'ap'],
#  ['vitiello', 'tapped', 'a', 'acting', 'ice', 'director', 'via'],
#  ['will',
#   'reach',
#   'over',
#   'this',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'and',
#   'built',
#   'for',
#   'mobile',
#   'winning',
#   'strategy',
#   'amp',
#   'show',
#   'in',
#   'earnings'],
#  ['by', 'monday', 'morning'],
#  ['this', 'is', 'heading', 'to', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'baird',
#   'downgrade',
#   'with',
#   'rating',
#   'of',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['there',
#   'have',
#   'been',
#   'acquisition',
#   'for',
#   'total',
#   'of',
#   'share',
#   'over',
#   'the',
#   'past',
#   'week',
#   'for'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['buy', 'zone'],
#  [],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continues',
#   'to',
#   'tighten',
#   'bbl',
#   'is',
#   'getting',
#   'closer'],
#  ['one', 'of', 'the', 'greatest', 'buy'],
#  ['looking',
#   'at',
#   'the',
#   'yearly',
#   'performance',
#   'did',
#   'better',
#   'than',
#   'of',
#   'all',
#   'other',
#   'stock'],
#  ['at',
#   'amp',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'telecommunication',
#   'dividend'],
#  ['that',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'the',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividend'],
#  ['not', 'talking', 'about', 'wa', 'referring', 'to', 'intelsat'],
#  ['will',
#   'punish',
#   'seller',
#   'who',
#   'don',
#   'move',
#   'stock',
#   'from',
#   'it',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miner',
#   'and',
#   'other',
#   'gpu',
#   'enthusiast',
#   'have',
#   'been',
#   'waiting',
#   'over',
#   'two',
#   'year',
#   'for',
#   'the',
#   'company',
#   'next',
#   'big'],
#  ['ha',
#   'only',
#   'medium',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['today', 'insight', 'on'],
#  ['what', 'will', 'be', 'more', 'in', 'five', 'year', 'baba', 'or', 'apple'],
#  ['next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trending'],
#  ['we',
#   'will',
#   'get',
#   'riiiiiiiiiich',
#   'sooooon',
#   'buuuuls',
#   'looooove',
#   'you',
#   'all',
#   'and',
#   'fucking',
#   'drunk'],
#  ['if',
#   'this',
#   'doesn',
#   'get',
#   'through',
#   'it',
#   'going',
#   'to',
#   'make',
#   'new',
#   'low',
#   'when',
#   'it',
#   'pay',
#   'the',
#   'dividend'],
#  ['gapping', 'up', 'monday'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'hold',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['should',
#   'by',
#   'warbey',
#   'parker',
#   'for',
#   'in',
#   'prep',
#   'for',
#   'apple',
#   'glass',
#   'a',
#   'seen',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'on',
#   'fashion',
#   'and',
#   'tech',
#   'wrt',
#   'wearable'],
#  ['look',
#   'like',
#   'sbux',
#   'is',
#   'paying',
#   'full',
#   'sex',
#   'change',
#   'for',
#   'employee',
#   'now',
#   'that',
#   'll',
#   'hit',
#   'the',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'up',
#   'to',
#   'other',
#   'trade',
#   'included',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['enterprise',
#   'value',
#   'v',
#   'market',
#   'cap',
#   'difference',
#   'of',
#   'actual',
#   'asset',
#   'v',
#   'market',
#   'value',
#   'too',
#   'big',
#   'spread',
#   'way',
#   'undervalued'],
#  ['million', 'share', 'added', 'on', 'june', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'will',
#   'become',
#   'such',
#   'monopoly',
#   'dipping',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'is',
#   'possibility',
#   'do'],
#  ['don',
#   'miss',
#   'the',
#   'breakout',
#   'on',
#   'buy',
#   'stop',
#   'stop',
#   'loss',
#   'is',
#   'suggested',
#   'by',
#   'the',
#   'chartmill',
#   'analyzer'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'resistance',
#   'other',
#   'trade',
#   'included',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'ha',
#   'moved',
#   'since',
#   'post',
#   'reversal',
#   'in',
#   'progress',
#   'other',
#   'trade',
#   'included',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['ve',
#   'recently',
#   'closed',
#   'my',
#   'position',
#   'in',
#   'for',
#   'now',
#   'is',
#   'probably',
#   'next',
#   'on',
#   'the',
#   'list',
#   'bought',
#   'both',
#   'in',
#   'the',
#   'same',
#   'week'],
#  ['nat',
#   'ricciardi',
#   'is',
#   'director',
#   'used',
#   'to',
#   'be',
#   'president',
#   'of',
#   'global',
#   'manufacturing'],
#  ['according',
#   'to',
#   'data',
#   'reported',
#   'to',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'for',
#   'clocked',
#   'in',
#   'at',
#   'on'],
#  ['saudi',
#   'official',
#   'came',
#   'out',
#   'saying',
#   'they',
#   'didn',
#   'agree',
#   'to',
#   'this'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'uptrend',
#   'to',
#   'resume',
#   'other',
#   'trade',
#   'included',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['the',
#   'one',
#   'on',
#   'the',
#   'right',
#   'cover',
#   'the',
#   'penis',
#   'or',
#   'the',
#   'putang',
#   'the',
#   'front',
#   'leg',
#   'would',
#   'be',
#   'arm'],
#  [],
#  ['some', 'of', 'the', 'stock', 'am', 'watching', 'now'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'next',
#   'stop',
#   'other',
#   'trade',
#   'included',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['wonder',
#   'how',
#   'much',
#   'this',
#   'will',
#   'be',
#   'valued',
#   'at',
#   'in',
#   'year',
#   'we',
#   'are',
#   'not',
#   'even',
#   'in',
#   'the',
#   'th',
#   'inning'],
#  ['ha',
#   'bad',
#   'technical',
#   'rating',
#   'but',
#   'it',
#   'doe',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['is',
#   'going',
#   'to',
#   'make',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'watching',
#   'apple',
#   'think',
#   'they',
#   'shorted',
#   'the',
#   'put',
#   'spread',
#   'for',
#   'july'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'included',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['it',
#   'good',
#   'that',
#   'even',
#   'bull',
#   'are',
#   'cautious',
#   'stunned',
#   'bearish',
#   'deeply',
#   'disappointed',
#   'too',
#   'bad',
#   'continues',
#   'it',
#   'old',
#   'way',
#   'hopefully',
#   'we',
#   'are',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'included',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['ending', 'june', 'killed', 'it', 'best', 'month', 'since', 'february'],
#  ['funny',
#   'how',
#   'long',
#   'the',
#   'same',
#   'thing',
#   'ha',
#   'been',
#   'going',
#   'on',
#   'with',
#   'this',
#   'about',
#   'year',
#   'of',
#   'this',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measured',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'the',
#   'momentum',
#   'starting',
#   'to',
#   'shi'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintains',
#   'with',
#   'rating',
#   'of',
#   'buy',
#   'setting',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'is',
#   'buy'],
#  ['google', 'venture', 'company'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'it',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'it',
#   'come',
#   'is',
#   'year',
#   'down',
#   'the',
#   'line',
#   'keep',
#   'buying',
#   'short',
#   'pure',
#   'bull'],
#  ['beanscreen', 'for'],
#  ['the',
#   'min',
#   'chart',
#   'from',
#   'friday',
#   'indicating',
#   'some',
#   'nice',
#   'accumulation',
#   'at',
#   'eod',
#   'could',
#   'be',
#   'nice',
#   'pop',
#   'monday'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   'is',
#   'via'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'apog',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo'],
#  ['can', 'we', 'squeeze', 'the', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'pullback',
#   'to',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'included',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog'],
#  ['still', 'holding', 'call', 'for', 'next', 'week'],
#  ['is', 'safe', 'but', 'their', 'buyback', 'yield', 'is', 'div', 'yield'],
#  ['adding',
#   'at',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'a',
#   'long',
#   'a',
#   'possible',
#   'excess',
#   'gain',
#   'are',
#   'welcome',
#   'gl'],
#  ['looking',
#   'at',
#   'friday',
#   'data',
#   'seeing',
#   'different',
#   'story',
#   'on',
#   'the',
#   'chart',
#   'take',
#   'look',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['bouncing',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful',
#   'for'],
#  ['data',
#   'science',
#   'officially',
#   'became',
#   'major',
#   'in',
#   'university',
#   'this',
#   'year',
#   'to',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'are',
#   'no',
#   'brainers',
#   'in',
#   'the',
#   'data',
#   'era'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'support',
#   'at',
#   'other',
#   'trade',
#   'included',
#   'payx',
#   'fdx',
#   'goo',
#   'nvda',
#   'apog',
#   'acn',
#   'camp'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  [],
#  ['ha',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['second', 'not', 'minute'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'rule',
#   'applies',
#   'here',
#   'other',
#   'trade',
#   'included',
#   'zbra',
#   'six',
#   'fc',
#   'gbx',
#   'fds',
#   'avav',
#   'baba'],
#  ['trump',
#   'is',
#   'killing',
#   'the',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'and',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   'doing',
#   'right',
#   'now'],
#  ['haven',
#   'posted',
#   'on',
#   'stocktwits',
#   'in',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good'],
#  ['today', 'insight', 'on'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amazing'],
#  ['stock',
#   'have',
#   'contributed',
#   'of',
#   'ytd',
#   'return',
#   'what',
#   'do',
#   'you',
#   'own'],
#  ['today', 'insight', 'on'],
#  ['my', 'rd', 'most', 'popular', 'word'],
#  ['trump',
#   'tweet',
#   'and',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'it',
#   'rain',
#   'up',
#   'in',
#   'the',
#   'white',
#   'house'],
#  ['ha',
#   'poor',
#   'technical',
#   'rating',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'setup',
#   'is',
#   'also',
#   'not',
#   'perfect',
#   'at',
#   'the',
#   'moment'],
#  ['doubt',
#   'it',
#   'go',
#   'down',
#   'monday',
#   'and',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measured',
#   'over',
#   'the',
#   'past',
#   'year',
#   'show',
#   'very',
#   'strong',
#   'growth',
#   'in',
#   'eps'],
#  ['constellation', 'brand'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jumping',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'given',
#   'the',
#   'price',
#   'action'],
#  ['here'],
#  ['did', 'disney', 'just', 'clinch', 'the', 'deal', 'to', 'acquire', 'fox'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['aggregate',
#   'short',
#   'volume',
#   'reported',
#   'to',
#   'finra',
#   'for',
#   'wa',
#   'on'],
#  ['southwest',
#   'airline',
#   'is',
#   'adding',
#   'flight',
#   'in',
#   'dallas',
#   'a',
#   'delta',
#   'spat',
#   'continues'],
#  ['what', 'california'],
#  ['better', 'buy', 'netflix', 'inc', 'nflx', 'versus', 'facebook', 'fb'],
#  ['one', 'thing', 'that', 'starbucks', 'is', 'doing', 'wrong'],
#  [],
#  ['using',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lost',
#   'in',
#   'on'],
#  ['bull',
#   'list',
#   'after',
#   'their',
#   'emergence',
#   'from',
#   'bankruptcy',
#   'emergency'],
#  ['zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh'],
#  ['list', 'of', 'tyzen', 'and', 'vega', 'laptop', 'a', 'of', 'june', 'th'],
#  ['investing',
#   'in',
#   'the',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   'yr',
#   'bond',
#   'continue',
#   'to',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'the',
#   'country',
#   'is',
#   'growing',
#   'amd',
#   'is'],
#  ['list', 'of', 'ryzen', 'and', 'vega', 'laptop', 'a', 'of'],
#  ['gettin', 'blasted'],
#  ['weekly',
#   'recap',
#   'price',
#   'moved',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'at',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'included',
#   'cgnx',
#   'cx',
#   'aaoi',
#   'aa',
#   'amswa',
#   'yy',
#   'snx'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'am',
#   'definitely',
#   'jumping',
#   'into',
#   'the',
#   'august',
#   'put',
#   'on',
#   'monday'],
#  ['so',
#   'is',
#   'g',
#   'going',
#   'to',
#   'give',
#   'u',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earnings'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['huge', 'volume', 'at', 'closing', 'on', 'friday'],
#  ['looking', 'for', 'scalp'],
#  ['this',
#   'is',
#   'one',
#   'giant',
#   'fermenting',
#   'turd',
#   'of',
#   'stock',
#   'when',
#   'will',
#   'it',
#   'go',
#   'back',
#   'up',
#   'to'],
#  ['buffet', 'and', 'are', 'buying', 'at', 'per', 'share'],
#  ['in', 'put', 'from', 'last', 'week', 'target', 'zone', 'marked'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good'],
#  ['mitch',
#   'did',
#   'great',
#   'job',
#   'of',
#   'getting',
#   'netflix',
#   'started',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'to',
#   'make',
#   'big',
#   'thing',
#   'happen',
#   'in',
#   'this',
#   'industry'],
#  ['cup',
#   'and',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['with',
#   'debt',
#   'to',
#   'equity',
#   'ratio',
#   'of',
#   'is',
#   'doing',
#   'better',
#   'than',
#   'the',
#   'average',
#   'in',
#   'the',
#   'industry'],
#  ['sell',
#   'in',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'ha',
#   'been',
#   'pattern',
#   'for',
#   'year',
#   'interesting',
#   'to',
#   'see',
#   'so',
#   'much',
#   'trading',
#   'in',
#   'this',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'trader'],
#  ['meanwhile', 'in', 'galaxy', 'far', 'far', 'away'],
#  ['broadening',
#   'wedge',
#   'descending',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy', 'trading', 'guy', 'looking', 'to', 'exit', 'today'],
#  ['large', 'put', 'spread', 'in', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'coke',
#   'and',
#   'smile',
#   'thanks',
#   'for',
#   'the',
#   'dividend',
#   'and'],
#  [],
#  ['selling', 'will', 'prove', 'to', 'be', 'terrible', 'error'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'article',
#   'just',
#   'posted',
#   'hint',
#   'at',
#   'possible',
#   'acquisition',
#   'of',
#   'sogou',
#   'finger',
#   'crossed'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['bro',
#   'that',
#   'not',
#   'how',
#   'it',
#   'work',
#   'delete',
#   'the',
#   'blue',
#   'arrow',
#   'that',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'is',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'it',
#   'close',
#   'under',
#   'the',
#   'ma',
#   'on',
#   'the',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'is',
#   'changing'],
#  ['cup',
#   'and',
#   'holder',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['hi',
#   'everyone',
#   'going',
#   'to',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepared'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['amazon',
#   'new',
#   'warehouse',
#   'policy',
#   'will',
#   'start',
#   'penalizing',
#   'seller',
#   'that',
#   'store',
#   'product',
#   'for',
#   'too',
#   'long'],
#  ['just',
#   'fyi',
#   'trump',
#   'era',
#   'ramp',
#   'up',
#   'tech',
#   'worker',
#   'revolt',
#   'the',
#   'hill'],
#  ['this',
#   'company',
#   'going',
#   'off',
#   'the',
#   'rail',
#   'the',
#   'people',
#   'that',
#   'work',
#   'there',
#   'and',
#   'the',
#   'store',
#   'manager',
#   'say',
#   'it',
#   'all',
#   'circuit',
#   'city',
#   'deux'],
#  ['why',
#   'did',
#   'bank',
#   'fail',
#   'to',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'and',
#   'div',
#   'incr',
#   'me',
#   'thinking',
#   'mm',
#   'driving',
#   'down',
#   'price',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'cheap',
#   'prior',
#   'the',
#   'rally'],
#  ['bear',
#   'using',
#   'all',
#   'argument',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'are',
#   'becoming',
#   'loses',
#   'this',
#   'week'],
#  ['gameranx', 'popular', 'youtube', 'gaming', 'channel'],
#  ['facebook', 'the', 'cash', 'machine'],
#  ['and',
#   'it',
#   'will',
#   'take',
#   'all',
#   'semi',
#   'up',
#   'more',
#   'week',
#   'and',
#   'then',
#   'uptrend',
#   'continues'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   'altria',
#   'aflac',
#   'eatonvance'],
#  ['look',
#   'at',
#   'the',
#   'graph',
#   'tripple',
#   'bottom',
#   'reached',
#   'for',
#   'heading',
#   'to',
#   'and',
#   'to',
#   'in',
#   'to',
#   'week'],
#  ['if',
#   'you',
#   'have',
#   'penis',
#   'and',
#   'want',
#   'vagina',
#   'like',
#   'alteration',
#   'go',
#   'get',
#   'job',
#   'at',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'in',
#   'display',
#   'market',
#   'data'],
#  ['facebook', 'the', 'cash', 'machine'],
#  [],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['microsoft',
#   'andromeda',
#   'leak',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'in',
#   'your',
#   'pocket'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['ha',
#   'good',
#   'piotroski',
#   'score',
#   'of',
#   'this',
#   'indicates',
#   'good',
#   'health',
#   'and',
#   'profitability'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shit',
#   'the',
#   'bed'],
#  ['bullish', 'bat', 'bullish', 'bat', 'with', 'bullish', 'divergence'],
#  ['epyc',
#   'server',
#   'adoption',
#   'will',
#   'snow',
#   'ball',
#   'this',
#   'year',
#   'intel',
#   'security',
#   'flaw',
#   'nm',
#   'fail',
#   'fire',
#   'ceo',
#   'you',
#   'can',
#   'make',
#   'this',
#   'sh',
#   'up'],
#  ['my',
#   'original',
#   'thesis',
#   'wa',
#   'predicated',
#   'on',
#   'amd',
#   'having',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'sh',
#   'the',
#   'bed'],
#  ['think', 'will', 'buy', 'a', 'many', 'a', 'can', 'under'],
#  ['new', 'way', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['wowza',
#   'for',
#   'if',
#   'started',
#   'one',
#   'month',
#   'ago',
#   'the',
#   'short',
#   'return',
#   'would',
#   'be',
#   'around',
#   'a',
#   'of',
#   'iex',
#   'data'],
#  ['is',
#   'the',
#   'real',
#   'boom',
#   'in',
#   'the',
#   'social',
#   'medium',
#   'and',
#   'it',
#   'will',
#   'get',
#   'much',
#   'bigger',
#   'it',
#   'will',
#   'be',
#   'in',
#   'before',
#   'christmas'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'is',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['celgene',
#   'investor',
#   'breathe',
#   'sigh',
#   'of',
#   'relief',
#   'after',
#   'acceleron',
#   'success'],
#  ['bear',
#   'and',
#   'shorties',
#   'made',
#   'huge',
#   'mistake',
#   'and',
#   'they',
#   'don',
#   'have',
#   'the',
#   'money',
#   'to',
#   'buy',
#   'back',
#   'when',
#   'shorted',
#   'it',
#   'at',
#   'so',
#   'they',
#   'cry',
#   'out',
#   'here',
#   'everyday'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'industry',
#   'average',
#   'roa',
#   'is',
#   'outperforms',
#   'of',
#   'it',
#   'industry',
#   'peer'],
#  ['encourage',
#   'you',
#   'to',
#   'no',
#   'longer',
#   'be',
#   'sheep',
#   'end',
#   'your',
#   'racist',
#   'and',
#   'hateful',
#   'way',
#   'buy',
#   'amd',
#   'and',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'democratic',
#   'party',
#   'walkaway'],
#  ['it',
#   'happening',
#   'looking',
#   'to',
#   'ease',
#   'the',
#   'flattening',
#   'of',
#   'the',
#   'yc',
#   'starting',
#   'this',
#   'week',
#   'lot',
#   'of',
#   'trader',
#   'def',
#   'offside',
#   'now'],
#  ['daily', 'or', 'weekly', 'chart', 'all', 'look', 'horrible'],
#  ['if', 'spotify', 'add', 'more', 'video', 'content', 'look', 'out'],
#  ['market',
#   'positioning',
#   'is',
#   'very',
#   'underweight',
#   'crowdthnk',
#   'algo',
#   'forecast',
#   'chance',
#   'moving',
#   'lower'],
#  ['added',
#   'more',
#   'at',
#   'this',
#   'no',
#   'brainer',
#   'if',
#   'you',
#   're',
#   'long',
#   'there',
#   'is',
#   'no',
#   'peer',
#   'and',
#   'they',
#   'are',
#   'top',
#   'dog',
#   'amd',
#   'and',
#   'mu',
#   'notwithstanding'],
#  ['bearish',
#   'bat',
#   'bearish',
#   'bat',
#   'with',
#   'some',
#   'serious',
#   'bearish',
#   'divergence',
#   'something',
#   'is',
#   'about',
#   'to',
#   'give'],
#  ['ha',
#   'been',
#   'proposition',
#   'in',
#   'july',
#   'since',
#   'with',
#   'net',
#   'return',
#   'of'],
#  ['in',
#   'term',
#   'of',
#   'negative',
#   'for',
#   'there',
#   'are',
#   'bearish',
#   'indicator',
#   'a',
#   'of'],
#  ['quite', 'over', 'valued', 'in', 'my', 'opinion'],
#  ['brexit',
#   'banker',
#   'risk',
#   'life',
#   'on',
#   'the',
#   'edge',
#   'a',
#   'luxembourg',
#   'fill',
#   'up',
#   'via'],
#  ['market', 'history'],
#  ['so', 'amd', 'is', 'using', 'liquid', 'inside', 'of', 'the', 'gpu'],
#  ['curve',
#   'flattening',
#   'juggernaut',
#   'face',
#   'risk',
#   'from',
#   'fed',
#   'concern',
#   'on',
#   'trade',
#   'via'],
#  ['a',
#   'it',
#   'pertains',
#   'to',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'a',
#   'of',
#   'according',
#   'to',
#   'iex'],
#  [],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['study',
#   'of',
#   'watchlist',
#   'trade',
#   'wisely',
#   'invest',
#   'wisely',
#   'read',
#   'the',
#   'wallstreet',
#   'runner'],
#  ['waiting', 'for', 'the', 'pull', 'back', 'slow', 'steady', 'stock'],
#  ['thought',
#   'friday',
#   'flush',
#   'wa',
#   'for',
#   'cheap',
#   'share',
#   'just',
#   'like',
#   'they',
#   'did',
#   'in',
#   'oil',
#   'before',
#   'the',
#   'opec',
#   'meeting'],
#  ['china', 'attack'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['is',
#   'rated',
#   'sell',
#   'since',
#   'june',
#   'and',
#   'is',
#   'below',
#   'it',
#   'median',
#   'level'],
#  ['dont', 'trust', 'this', 'company'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'anticipation',
#   'is',
#   'rising',
#   'which',
#   'analyst',
#   'is',
#   'right',
#   'june'],
#  ['sorry',
#   'itsallaboutheoptions',
#   'stock',
#   'price',
#   'is',
#   'not',
#   'so',
#   'we',
#   'are',
#   'higher',
#   'than',
#   'you',
#   'predicted',
#   'not',
#   'lower'],
#  ['warren', 'diggered', 'a', 'they', 'exited'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'at',
#   'is',
#   'via'],
#  ['another', 'analyst', 'opinion', 'on', 'june'],
#  [],
#  ['and',
#   'are',
#   'all',
#   'down',
#   'because',
#   'of',
#   'trade',
#   'concern',
#   'will',
#   'still',
#   'be',
#   'worth',
#   'it',
#   'weight',
#   'in',
#   'faucet',
#   'and',
#   'now',
#   'little',
#   'bit',
#   'of',
#   'lighting'],
#  ['three',
#   'falling',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['rectangle',
#   'top',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['any', 'more', 'really', 'jetsonbs', 'design', 'they', 'announce'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['cogsworth', 'cog', 'will', 'take', 'on', 'boeing', 'soon', 'right'],
#  ['really',
#   'baked',
#   'right',
#   'now',
#   'having',
#   'deep',
#   'thought',
#   'short',
#   'coming',
#   'back',
#   'to',
#   'look',
#   'at',
#   'this',
#   'tweet',
#   'in',
#   'year'],
#  ['this',
#   'one',
#   'will',
#   'test',
#   'if',
#   'fails',
#   'my',
#   'target',
#   'is',
#   'to',
#   'start',
#   'buying',
#   'this',
#   'again',
#   'houseofpain'],
#  ['analyst', 'opinion'],
#  ['making', 'more', 'than', 'ever', 'thanks', 'to', 'amp'],
#  [],
#  ['atl', 'fed', 'forecast', 'whew', 'baby', 'up', 'we', 'go'],
#  ['here',
#   'it',
#   'is',
#   'june',
#   'grr',
#   'date',
#   'is',
#   'came',
#   'out',
#   'early',
#   'read',
#   'away'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['stericycle',
#   'current',
#   'chance',
#   'of',
#   'distress',
#   'is',
#   'about',
#   'below',
#   'average'],
#  ['ggr', 'is', 'out', 'for', 'june'],
#  ['today', 'insight', 'on'],
#  ['fyi'],
#  ['will', 'this', 'go', 'over', 'before', 'earnings'],
#  ['extremely',
#   'undervalued',
#   'this',
#   'will',
#   'be',
#   'within',
#   'year',
#   'great',
#   'for',
#   'midterm',
#   'investment'],
#  ['may', 'go', 'slightly', 'down', 'on', 'this', 'news', 'june', 'ggr'],
#  ['stupid', 'spammer', 'wasting', 'time'],
#  ['but',
#   'it',
#   'already',
#   'oversold',
#   'so',
#   'not',
#   'much',
#   'consolidation',
#   'and',
#   'then',
#   'up'],
#  ['this', 'is', 'just', 'the', 'start'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thursday',
#   'and',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['june',
#   'ggr',
#   'up',
#   'still',
#   'after',
#   'the',
#   'soccer',
#   'world',
#   'cup',
#   'and',
#   'holiday'],
#  ['purchasing',
#   'pill',
#   'pack',
#   'last',
#   'thurs',
#   'amp',
#   'breaking',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['buy', 'back', 'they', 'want', 'cheap'],
#  ['not',
#   'too',
#   'expensive',
#   'and',
#   'growing',
#   'strongly',
#   'check',
#   'out',
#   'now',
#   'part',
#   'of',
#   'our',
#   'affordable',
#   'growth',
#   'selection'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['the',
#   'long',
#   'term',
#   'trend',
#   'is',
#   'positive',
#   'and',
#   'the',
#   'short',
#   'term',
#   'trend',
#   'is',
#   'neutral',
#   'so',
#   'the',
#   'benefit',
#   'of',
#   'the',
#   'doubt',
#   'for',
#   'now'],
#  ['lot',
#   'of',
#   'buyer',
#   'fri',
#   'when',
#   'mm',
#   'pinned',
#   'at',
#   'quot',
#   'trader',
#   'buy',
#   'amazon',
#   'com',
#   'amzn',
#   'on',
#   'weakness',
#   'quot'],
#  ['in',
#   'term',
#   'of',
#   'positive',
#   'for',
#   'there',
#   'are',
#   'bullish',
#   'indicator',
#   'a',
#   'of'],
#  ['know', 'what', 'hold'],
#  ['never',
#   'have',
#   'seen',
#   'right',
#   'angle',
#   'in',
#   'apple',
#   'lol',
#   'that',
#   'wa',
#   'crazy'],
#  ['wanna',
#   'hear',
#   'the',
#   'er',
#   'ok',
#   'yeah',
#   'all',
#   'got',
#   'great',
#   'product',
#   'so',
#   'what',
#   'this',
#   'is',
#   'the',
#   'stock',
#   'market',
#   'want',
#   'report',
#   'what',
#   'the',
#   'news'],
#  ['starbucks',
#   'to',
#   'become',
#   'the',
#   'pioneer',
#   'in',
#   'medical',
#   'coverage',
#   'for',
#   'sex',
#   'change',
#   'get',
#   'your',
#   'free',
#   'sex',
#   'change',
#   'here'],
#  ['today', 'insight', 'on'],
#  ['today', 'insight', 'on'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['all',
#   'in',
#   'on',
#   'august',
#   'call',
#   'either',
#   'gonna',
#   'make',
#   'fortune',
#   'or',
#   'declare',
#   'bankruptcy'],
#  ['wtf'],
#  [],
#  ['macau', 'casino', 'ggr', 'up', 'nearly', 'pct', 'in', 'june', 'govt'],
#  ['jul',
#   'casino',
#   'gross',
#   'gaming',
#   'revenue',
#   'ggr',
#   'in',
#   'macau',
#   'rose',
#   'by',
#   'percent',
#   'year',
#   'on',
#   'year',
#   'in',
#   'june',
#   'to'],
#  ['what'],
#  ['is', 'gonna', 'be', 'cheaper', 'than', 'also'],
#  ['the',
#   'monster',
#   'core',
#   'amd',
#   'ryzen',
#   'threadripper',
#   'cpu',
#   'rumored',
#   'usd'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'a',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['someone', 'give', 'me', 'like'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  [],
#  ['valued', 'll', 'take', 'at', 'this', 'point'],
#  [],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['trump', 'will', 'cause', 'oil', 'price', 'to', 'go', 'down'],
#  ['if',
#   'were',
#   'and',
#   'need',
#   'to',
#   'buyback',
#   'bln',
#   'share',
#   'wouldn',
#   'try',
#   'to',
#   'buy',
#   'the',
#   'dip'],
#  ['option',
#   'volume',
#   'wa',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'wa',
#   'and',
#   'put',
#   'volume',
#   'wa'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'is', 'via'],
#  ['gigabyte', 'amp', 'epyc', 'cpu', 'with', 'large', 'density', 'server'],
#  ['now',
#   'intel',
#   'can',
#   'produce',
#   'full',
#   'silicon',
#   'wafer',
#   'for',
#   'quantum',
#   'computing',
#   'chip'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['good',
#   'technical',
#   'but',
#   'also',
#   'nice',
#   'setup',
#   'pattern',
#   'forming',
#   'for',
#   'now',
#   'part',
#   'of',
#   'our',
#   'top',
#   'breakout',
#   'selection'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['june',
#   'ggr',
#   'only',
#   'up',
#   'very',
#   'bad',
#   'stock',
#   'are',
#   'going',
#   'to',
#   'get',
#   'crushed'],
#  ['amazon',
#   'with',
#   'hook',
#   'pattern',
#   'set',
#   'up',
#   'on',
#   'the',
#   'monthly',
#   'looking',
#   'at',
#   'strong',
#   'move',
#   'up',
#   'on',
#   'monday',
#   'expected'],
#  ['paychex',
#   'social',
#   'hype',
#   'low',
#   'key',
#   'current',
#   'chance',
#   'of',
#   'financial',
#   'distress',
#   'is',
#   'under'],
#  ['today', 'insight', 'on'],
#  [],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['buy', 'more', 'on', 'the', 'dip', 'buying', 'opp'],
#  ['here',
#   'is',
#   'an',
#   'example',
#   'of',
#   'hook',
#   'pattern',
#   'virtually',
#   'identical',
#   'to',
#   'what',
#   'amazon',
#   'monthly',
#   'chart',
#   'look',
#   'like',
#   'now'],
#  ['the',
#   'eps',
#   'ha',
#   'been',
#   'growing',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'year',
#   'this',
#   'is',
#   'quite',
#   'good'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['showing', 'up', 'in', 'our', 'top', 'breakout', 'selection'],
#  ['overbought', 'sell', 'signal'],
#  ['short', 'ratio', 'is', 'at', 'and', 'short', 'to', 'float', 'is', 'via'],
#  ['rsi', 'deathcross'],
#  ['will',
#   'be',
#   'selling',
#   'pre',
#   'market',
#   'and',
#   'trying',
#   'to',
#   'buy',
#   'in',
#   'very',
#   'bullish',
#   'but',
#   'would',
#   'like',
#   'to',
#   'take',
#   'advantage',
#   'of',
#   'dip'],
#  ['a',
#   'it',
#   'pertains',
#   'to',
#   'if',
#   'started',
#   'day',
#   'ago',
#   'bearish',
#   'investor',
#   'would',
#   'have',
#   'lost',
#   'around',
#   'a',
#   'of',
#   'according',
#   'to',
#   'iex'],
#  ['short',
#   'volume',
#   'for',
#   'on',
#   'wa',
#   'th',
#   'percentile',
#   'in',
#   'term',
#   'of',
#   'last',
#   'trading',
#   'day'],
#  ['bring',
#   'on',
#   'the',
#   'gloom',
#   'amp',
#   'doom',
#   'on',
#   'the',
#   'pull',
#   'back',
#   'ahead',
#   'of',
#   'er',
#   'happens',
#   'ever',
#   'time',
#   'after',
#   'don',
#   'fight',
#   'the',
#   'plan',
#   'buy',
#   'it',
#   'no',
#   'way',
#   'it',
#   'fall'],
#  ['overbought', 'death', 'cross', 'sell', 'signal'],
#  ['short',
#   'interest',
#   'ratio',
#   'is',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['bad',
#   'news',
#   'is',
#   'baked',
#   'in',
#   'to',
#   'the',
#   'sector',
#   'but',
#   'second',
#   'major',
#   'miss',
#   'in',
#   'row',
#   'like',
#   'this',
#   'is',
#   'going',
#   'to',
#   'spook',
#   'lot',
#   'of',
#   'investor'],
# ...
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['ba', 'ba'],
#  ['not', 'at', 'all', 'afraid', 'to', 'hold', 'my', 'short', 'in', 'bank'],
#  ['retaliation',
#   'for',
#   'u',
#   'tariff',
#   'on',
#   'sun',
#   'canada',
#   'on',
#   'july',
#   'china',
#   'expected',
#   'to',
#   'impose',
#   'tariff',
#   'on',
#   'u',
#   'soybean',
#   'cnbc'],
#  ['short',
#   'ratio',
#   'of',
#   'is',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'is',
#   'via'],
#  ['wonder', 'how', 'many', 'matebook', 'are', 'selling'],
#  ['bac', 'bac'],
#  ['good', 'plan', 'right', 'here', 'close', 'to', 'mine'],
#  ['very', 'optimistic', 'melikey'],
#  ['high',
#   'oi',
#   'range',
#   'is',
#   'to',
#   'for',
#   'option',
#   'expiration',
#   'maxpain',
#   'option'],
#  ['oversold', 'with', 'sign', 'of', 'possible', 'reversal'],
#  ['would',
#   'not',
#   'want',
#   'to',
#   'be',
#   'in',
#   'this',
#   'for',
#   'the',
#   'next',
#   'er'],
#  ['don', 'tell', 'me', 'you', 'are', 'still', 'holding'],
#  ['ok',
#   'you',
#   'keep',
#   'telling',
#   'telling',
#   'yourself',
#   'that',
#   'he',
#   'bked',
#   'casino',
#   'casino',
#   'now',
#   'and',
#   'soon'],
#  ['this',
#   'is',
#   'the',
#   'only',
#   'table',
#   'service',
#   'can',
#   'afford',
#   'right',
#   'now',
#   'can',
#   'even',
#   'afford',
#   'the',
#   'mcdouble',
#   'anymore',
#   'after',
#   'the',
#   'price',
#   'hike'],
#  ['can',
#   'someone',
#   'explain',
#   'what',
#   'happens',
#   'with',
#   'the',
#   'div',
#   'payout',
#   'if',
#   'buy',
#   'in',
#   'here'],
#  ['economy',
#   'that',
#   'time',
#   'sending',
#   'job',
#   'overseas',
#   'after',
#   'supporting',
#   'them',
#   'gut',
#   'of',
#   'trump',
#   'calling',
#   'them',
#   'out'],
#  ['yeah', 'sleep', 'with', 'elon', 'musk'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed'],
#  ['if',
#   'all',
#   'be',
#   'nice',
#   'to',
#   'me',
#   'can',
#   'give',
#   'you',
#   'an',
#   'accurate',
#   'direction',
#   'of',
#   'which',
#   'way',
#   'this',
#   'will',
#   'go'],
#  ['below',
#   'all',
#   'sma',
#   'in',
#   'falling',
#   'wedge',
#   'bearish',
#   'until',
#   'breakout'],
#  ['think',
#   'most',
#   'of',
#   'the',
#   'peep',
#   'on',
#   'here',
#   'have',
#   'blocked',
#   'bro',
#   'time',
#   'to',
#   'use',
#   'an',
#   'alternate',
#   'account',
#   'sr',
#   'are',
#   'taken'],
#  ['you',
#   'bet',
#   'how',
#   'about',
#   'show',
#   'some',
#   'fact',
#   'sport',
#   'now',
#   'ha',
#   'control',
#   'of',
#   'nfl',
#   'mlb',
#   'march',
#   'madness',
#   'etc',
#   'roku',
#   'suck',
#   'donkey',
#   'dks'],
#  ['alibaba',
#   'buy',
#   'stake',
#   'in',
#   'turkey',
#   'trendyol',
#   'alibaba',
#   'is',
#   'proceeding',
#   'it',
#   'international',
#   'expansion'],
#  ['think',
#   'the',
#   'whole',
#   'dump',
#   'for',
#   'the',
#   'past',
#   'few',
#   'year',
#   'wa',
#   'absolutely',
#   'necessary',
#   'their',
#   'sht',
#   'wa',
#   'getting',
#   'way',
#   'too',
#   'expensive',
#   'they',
#   'can',
#   'grow',
#   'bter',
#   'now'],
#  ['if', 'feel', 'good', 'to', 'be', 'right', 'with', 'this', 'stock'],
#  ['remember',
#   'even',
#   'the',
#   'capital',
#   'investment',
#   'will',
#   'only',
#   'be',
#   'in',
#   'dividend',
#   'payout'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'dropped',
#   'reporting',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed'],
#  ['whats',
#   'up',
#   'bro',
#   'you',
#   'still',
#   'trade',
#   'this',
#   'stock',
#   'or',
#   'did',
#   'you',
#   'give',
#   'up'],
#  ['short', 'volume', 'percent', 'for', 'wa', 'on'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['talking',
#   'about',
#   'gravity',
#   'in',
#   'stock',
#   'market',
#   'is',
#   'fool',
#   'errond',
#   'take',
#   'look',
#   'at'],
#  ['read',
#   'your',
#   'comment',
#   'on',
#   'on',
#   'seeking',
#   'alpha',
#   'you',
#   'know',
#   'lot',
#   'about',
#   'casino',
#   'stock',
#   'will',
#   'this',
#   'ggr',
#   'hurt',
#   'the',
#   'price',
#   'more',
#   'or',
#   'ok',
#   'here'],
#  ['open', 'tomorrow'],
#  ['is',
#   'more',
#   'then',
#   'enough',
#   'we',
#   'should',
#   'be',
#   'at',
#   'and',
#   'earning',
#   'are',
#   'coming',
#   'up'],
#  ['should', 'be', 'loading', 'on', 'on', 'this', 'stock', 'here'],
#  ['wall',
#   'street',
#   'is',
#   'full',
#   'of',
#   'idiot',
#   'who',
#   'gamble',
#   'until',
#   'they',
#   'lose'],
#  ['hope',
#   'citibank',
#   'go',
#   'bankrupt',
#   'stealing',
#   'money',
#   'by',
#   'nickel',
#   'and',
#   'dimming',
#   'costumer',
#   'with',
#   'stupid',
#   'little',
#   'fee'],
#  [],
#  ['don',
#   'worry',
#   'scumbags',
#   'at',
#   'citibank',
#   'll',
#   'make',
#   'more',
#   'money',
#   'shorting',
#   'your',
#   'stock',
#   'to',
#   'the',
#   'ground',
#   'than',
#   'you',
#   'will',
#   'make',
#   'from',
#   'fee'],
#  ['choppy',
#   'head',
#   'amp',
#   'shoulder',
#   'watch',
#   'for',
#   'the',
#   'breakdown',
#   'watch',
#   'for',
#   'the',
#   'breakdown'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  [],
#  ['it', 'is', 'now', 'time', 'for', 'the', 'trumpy', 'bear', 'market'],
#  ['gravity',
#   'applies',
#   'to',
#   'overbot',
#   'condition',
#   'and',
#   'applied',
#   'to',
#   'in',
#   'past',
#   'a',
#   'well'],
#  ['highlight', 'in', 'cancer', 'from', 'the', 'week'],
#  ['jcp', 'jcpenney', 'ha', 'rev', 'per', 'employee', 'of'],
#  ['vrsk',
#   'beta',
#   'of',
#   'veriskanalytics',
#   'is',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['viavisolutions', 'dipped', 'by', 'in', 'the', 'last', 'year', 'viav'],
#  ['it', 'gartner', 'ha', 'very', 'low', 'roce', 'of'],
#  ['etn', 'the', 'rpe', 'revenue', 'per', 'employee', 'of', 'eatonplc', 'is'],
#  ['rrdonnelleysons',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   'of',
#   'rrd'],
#  ['ba', 'the', 'payout', 'ratio', 'of', 'boeing', 'is'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['psx', 'fcf', 'of', 'phillips', 'is'],
#  ['citigroup', 'ha', 'recommendation', 'mean', 'of'],
#  ['mco',
#   'sma',
#   'of',
#   'moody',
#   'is',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'up',
#   'by'],
#  ['fslr',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'firstsolar',
#   'is'],
#  ['aonplc',
#   'ha',
#   'beta',
#   'of',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'aon'],
#  ['microsoft', 'ha', 'adx', 'of', 'hinting', 'it', 'weak', 'trend', 'msft'],
#  ['apa',
#   'apache',
#   'ha',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by'],
#  ['yte', 'ha', 'ppo', 'of', 'incy'],
#  ['jmsmucker', 'ha', 'recommendation', 'mean', 'of', 'sjm'],
#  ['tel', 'teconnectivity', 'ha', 'ppo', 'of'],
#  ['operating', 'margin', 'of', 'internationalbusinessmachines', 'is', 'ibm'],
#  ['northerntrust', 'ha', 'recommendation', 'mean', 'of', 'ntrs'],
#  ['bankofnewyorkmellon', 'ha', 'short', 'of', 'float', 'of', 'bk'],
#  ['nowhere',
#   'to',
#   'go',
#   'but',
#   'up',
#   'focus',
#   'on',
#   'fundamental',
#   'epyc',
#   'v',
#   'xeon',
#   'tam',
#   'all',
#   'revenue',
#   'and',
#   'profit',
#   'coming',
#   'now',
#   'revenue',
#   'ramp',
#   'year',
#   'pt'],
#  ['etfc', 'insider', 'ownership', 'of', 'etrade', 'is'],
#  ['envisionhealthcare', 'ha', 'short', 'of', 'float', 'of', 'evhc'],
#  ['baxterinternational',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'bax'],
#  ['profit', 'margin', 'of', 'att', 'is'],
#  ['eogresources',
#   'is',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'eog'],
#  ['diamondoffshoredrilling',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'do'],
#  ['the', 'dividend', 'yield', 'of', 'averydennison', 'is', 'avy'],
#  ['southern',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'so'],
#  ['insider', 'ownership', 'of', 'davita', 'is', 'dva'],
#  ['western',
#   'ma',
#   'berkshire',
#   'cty',
#   'today',
#   'already',
#   'deg',
#   'today',
#   'the',
#   'cool',
#   'end',
#   'of',
#   'the',
#   'state'],
#  ['citizen', 'ha', 'stoch', 'of', 'making', 'it', 'oversold', 'cfg'],
#  ['bear',
#   'have',
#   'lost',
#   'on',
#   'alone',
#   'in',
#   'according',
#   'to',
#   'iex',
#   'data'],
#  ['cimarexco', 'ha', 'adx', 'of', 'signifying', 'it', 'weak', 'trend', 'xec'],
#  ['all', 'allstate', 'ha', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['cxo', 'conchoresources', 'went', 'up', 'by', 'in', 'the', 'last', 'year'],
#  ['compared',
#   'to',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'to',
#   'ebitda',
#   'ratio',
#   'of',
#   'is',
#   'valued',
#   'rather',
#   'cheaply'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['qepresources',
#   'ha',
#   'very',
#   'high',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'qep'],
#  ['ans', 'fcf', 'of', 'ansys', 'is'],
#  ['coty', 'the', 'recommendation', 'mean', 'of', 'coty', 'is'],
#  ['mtd', 'profit', 'margin', 'of', 'mettler', 'toledointernational', 'is'],
#  ['anyone', 'know', 'what', 'this', 'is', 'referring', 'to'],
#  ['gross', 'margin', 'of', 'motorolasolutions', 'is', 'msi'],
#  ['operating', 'margin', 'of', 'michaelkors', 'is', 'kor'],
#  ['allegionplc',
#   'is',
#   'overbought',
#   'according',
#   'to',
#   'it',
#   'stochastic',
#   'rsi',
#   'indicator',
#   'of',
#   'alle'],
#  ['nlsn',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'nielsennv',
#   'is'],
#  ['wpx', 'wpx', 'ha', 'rev', 'per', 'employee', 'of'],
#  ['whr', 'whirlpool', 'ha', 'dividend', 'yield', 'of'],
#  ['chrw', 'chrobinsonworldwide', 'ha', 'short', 'of', 'float', 'of'],
#  ['the', 'recommendation', 'mean', 'of', 'wellsfargo', 'is', 'wfc'],
#  ['ccl', 'carnival', 'ha', 'operating', 'margin', 'of'],
#  ['short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'is',
#   'via'],
#  ['sma',
#   'of',
#   'pepsico',
#   'is',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'pep'],
#  ['pfe', 'pfizer', 'ha', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'to',
#   'but',
#   'it',
#   'pull',
#   'back',
#   'to',
#   'and',
#   'the',
#   'sky',
#   'is',
#   'falling',
#   'lollll',
#   'the',
#   'nature',
#   'of',
#   'stock',
#   'is',
#   'up',
#   'and',
#   'down'],
#  ['deltaairlines',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'dal'],
#  ['adtalemglobaleducation', 'ha', 'operating', 'margin', 'of', 'atge'],
#  ['bsx', 'bostonscientific', 'ha', 'institutional', 'ownership', 'of'],
#  ['mck', 'mckesson', 'went', 'down', 'by', 'in', 'the', 'last', 'year'],
#  ['pbct',
#   'peoplesunited',
#   'is',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of'],
#  ['insider',
#   'ownership',
#   'of',
#   'vertexpharmaceuticalsorporated',
#   'is',
#   'vrtx'],
#  ['bkng', 'volatility', 'of', 'booking', 'is'],
#  ['dis', 'waltdisney', 'ha', 'ppo', 'of'],
#  ['abbottlaboratories', 'ha', 'insider', 'ownership', 'of', 'abt'],
#  ['arthurjgallagherco',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'ajg'],
#  ['disca', 'discoverycommunications', 'ha', 'gross', 'margin', 'of'],
#  ['lyondellbasellindustriesnv',
#   'ha',
#   'weak',
#   'trend',
#   'according',
#   'to',
#   'it',
#   'adx',
#   'of',
#   'lyb'],
#  ['so',
#   'basically',
#   'the',
#   'vip',
#   'and',
#   'premium',
#   'mass',
#   'aren',
#   'spending',
#   'a',
#   'much',
#   'analyst',
#   'fooled',
#   'by',
#   'the',
#   'appearance',
#   'given',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['skyworkssolutions', 'ha', 'institutional', 'ownership', 'of', 'swks'],
#  ['edisoninternational',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'weak',
#   'trend',
#   'eix'],
#  ['wmb', 'williamscompanies', 'ha', 'volatility', 'of'],
#  ['is',
#   'the',
#   'competition',
#   'profitable',
#   'yes',
#   'are',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['releasing',
#   'earnings',
#   'on',
#   'before',
#   'open',
#   'confirmed',
#   'anybody',
#   'buying',
#   'selling',
#   'in',
#   'earnings'],
#  ['kroger', 'ha', 'very', 'high', 'roce', 'of', 'kr'],
#  ['pcar', 'institutional', 'ownership', 'of', 'paccar', 'is'],
#  ['fcf', 'of', 'citrixsystems', 'is', 'ctxs'],
#  ['profit', 'margin', 'of', 'verisign', 'is', 'vrsn'],
#  ['honeywellinternational',
#   'ha',
#   'beta',
#   'of',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hon'],
#  ['the', 'dividend', 'yield', 'of', 'lincolnnational', 'is', 'lnc'],
#  ['txn',
#   'texasinstrumentsorporated',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tdc', 'short', 'percent', 'of', 'float', 'of', 'teradata', 'is'],
#  ['sma',
#   'of',
#   'smithao',
#   'is',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'is',
#   'now',
#   'down',
#   'by',
#   'aos'],
#  ['idexxlaboratories', 'ha', 'operating', 'margin', 'of', 'idxx'],
#  ['bby', 'bestbuyco', 'ha', 'revenue', 'per', 'employee', 'of'],
#  ['masco', 'ha', 'gross', 'margin', 'of', 'ma'],
#  ['the', 'payout', 'ratio', 'of', 'nike', 'is', 'nke'],
#  ['len', 'lennar', 'rose', 'by', 'in', 'the', 'last', 'month'],
#  ['clf', 'the', 'roce', 'of', 'cliffsnaturalresources', 'is'],
#  ['totalsystemservices',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'tss'],
#  ['symantec', 'dipped', 'by', 'in', 'the', 'last', 'year', 'symc'],
#  ['rrc', 'rangeresources', 'went', 'down', 'by', 'in', 'the', 'last', 'month'],
#  ['nsc', 'norfolksouther', 'ha', 'revenue', 'per', 'employee', 'of'],
#  ['the',
#   'return',
#   'on',
#   'capital',
#   'employed',
#   'of',
#   'accentureplc',
#   'is',
#   'acn'],
#  ['willistowerswatsonpublic',
#   'is',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'wltw'],
#  ['genworth', 'ha', 'institutional', 'ownership', 'of', 'gnw'],
#  ['martinmariettamaterials',
#   'ha',
#   'adx',
#   'of',
#   'signifying',
#   'it',
#   'strong',
#   'trend',
#   'mlm'],
#  ['intc', 'operating', 'margin', 'of', 'intel', 'is'],
#  ['operating', 'margin', 'of', 'affiliatedmanagers', 'is', 'amg'],
#  ['spgi', 'spglobal', 'ha', 'volatility', 'of'],
#  ['fbhs',
#   'beta',
#   'of',
#   'fortunebrandshomesecurity',
#   'is',
#   'making',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['nwl', 'newellbrands', 'dipped', 'by', 'in', 'the', 'last', 'year'],
#  ['coopercompanies', 'ha', 'operating', 'margin', 'of', 'coo'],
#  ['brighthouse',
#   'is',
#   'oversold',
#   'according',
#   'to',
#   'it',
#   'stoch',
#   'rsi',
#   'of',
#   'bhf'],
#  ['ebay', 'the', 'revenue', 'per', 'employee', 'of', 'ebay', 'is'],
#  ['slg', 'operating', 'margin', 'of', 'slgreenrealty', 'is'],
#  ['the', 'recommendation', 'mean', 'of', 'ppgindustries', 'is', 'ppg'],
#  ['tegna', 'dipped', 'by', 'in', 'the', 'last', 'month', 'tgna'],
#  ['dollargeneral', 'ha', 'gross', 'margin', 'of', 'dg'],
#  ['beta',
#   'of',
#   'hess',
#   'make',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'he'],
#  ['insider', 'ownership', 'of', 'vulcanmaterials', 'is', 'vmc'],
#  ['jpm',
#   'of',
#   'floating',
#   'share',
#   'of',
#   'jpmorganchaseco',
#   'are',
#   'being',
#   'shorted'],
#  ['beta',
#   'of',
#   'perrigo',
#   'is',
#   'making',
#   'it',
#   'le',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'prgo'],
#  ['mmc',
#   'marshmclennancompanies',
#   'ha',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tsn',
#   'tysonfoods',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'intercontinentalexchange',
#   'is',
#   'ice'],
#  ['bectondickinsonand',
#   'ha',
#   'adx',
#   'of',
#   'hinting',
#   'it',
#   'weak',
#   'trend',
#   'bdx'],
#  ['the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'fluor',
#   'is',
#   'flr'],
#  ['pdco',
#   'pattersoncompanies',
#   'ha',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['footlocker', 'rose', 'by', 'in', 'the', 'last', 'year', 'fl'],
#  ['we',
#   'have',
#   'detected',
#   'negative',
#   'indicator',
#   'a',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['aph', 'amphenol', 'ha', 'fcf', 'of'],
#  ...]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
from collections import Counter

"""
Create a vocabulary by using Bag of words
"""
stacked = [word for tok in tokenized for word in tok]

bow = Counter(stacked)
bow
# Out:
# Counter({'great': 17574,
#          'buy': 76326,
#          'at': 138460,
#          'ill': 883,
#          'wait': 11370,
#          'staanalystalert': 4072,
#          'for': 273550,
#          'jefferies': 1056,
#          'maintains': 903,
#          'with': 68866,
#          'rating': 15436,
#          'of': 211377,
#          'hold': 22152,
#          'setting': 3889,
#          'target': 16580,
#          'price': 37083,
#          'usd': 2955,
#          'our': 12209,
#          'own': 8970,
#          'verdict': 3736,
#          'is': 284906,
#          'heard': 1357,
#          'there': 25944,
#          'guy': 13433,
#          'who': 17884,
#          'know': 19936,
#          'someone': 5192,
#          'think': 24284,
#          'somebody': 1100,
#          'something': 6010,
#          'on': 241668,
#          'stocktwits': 1439,
#          'reveal': 196,
#          'yourself': 1207,
#          'why': 21706,
#          'the': 398911,
#          'drop': 17793,
#          'warren': 1015,
#          'buffet': 1301,
#          'taking': 6418,
#          'out': 56704,
#          'his': 6261,
#          'position': 11753,
#          'bear': 33566,
#          'have': 52966,
#          'reason': 7777,
#          'to': 379518,
#          'pay': 7609,
#          'more': 55368,
#          'attention': 3531,
#          'ok': 4567,
#          'good': 44208,
#          'we': 64757,
#          're': 13190,
#          'not': 68311,
#          'dropping': 2269,
#          'in': 205335,
#          'over': 32685,
#          'weekend': 3561,
#          'lol': 30941,
#          'daily': 14035,
#          'chart': 16004,
#          'need': 21657,
#          'get': 46708,
#          'back': 43061,
#          'above': 17856,
#          'per': 16565,
#          'week': 44055,
#          'after': 34396,
#          'spike': 2204,
#          'if': 59001,
#          'no': 40432,
#          'news': 19739,
#          'month': 16913,
#          'bo': 610,
#          'then': 20974,
#          'bingo': 181,
#          'what': 79145,
#          'odds': 392,
#          'strong': 17202,
#          'short': 86672,
#          'ratio': 7664,
#          'and': 208520,
#          'float': 4654,
#          'via': 23490,
#          'squeezing': 228,
#          'perfect': 1988,
#          'place': 2850,
#          'an': 22501,
#          'option': 20515,
#          'straddle': 2232,
#          'near': 5825,
#          'supporting': 276,
#          'trend': 8089,
#          'start': 8861,
#          'new': 46415,
#          'monday': 7383,
#          'expect': 10359,
#          'volume': 43709,
#          'across': 781,
#          'key': 8464,
#          'company': 22151,
#          'various': 84,
#          'sector': 5047,
#          'breakout': 6677,
#          'strategy': 1627,
#          'current': 6187,
#          'portfolio': 2469,
#          'bull': 27199,
#          'catalyst': 1284,
#          'continuing': 351,
#          'this': 203572,
#          'uptrend': 1688,
#          'pill': 196,
#          'pack': 191,
#          'amazon': 10934,
#          'prime': 1825,
#          'day': 67492,
#          'earnings': 52932,
#          'test': 4027,
#          'break': 17101,
#          'soon': 16160,
#          'ha': 44265,
#          'moved': 3368,
#          'check': 5455,
#          'movement': 2866,
#          'peer': 3180,
#          'mkm': 164,
#          'partner': 1166,
#          'set': 5841,
#          'it': 193551,
#          'too': 18991,
#          'early': 4770,
#          'tell': 4651,
#          'going': 48017,
#          'happen': 4281,
#          'even': 15815,
#          'about': 27608,
#          'raisinf': 1,
#          'output': 109,
#          'still': 35232,
#          'so': 45889,
#          'many': 9461,
#          'financially': 570,
#          'healthy': 1808,
#          'problem': 2754,
#          'meeting': 1002,
#          'obligation': 670,
#          'bullish': 25206,
#          'stock': 75468,
#          'watch': 14697,
#          'setup': 8108,
#          'timeframes': 39,
#          'blog': 539,
#          'by': 53983,
#          'just': 73196,
#          'high': 28326,
#          'alert': 12214,
#          'next': 46982,
#          'gt': 9390,
#          'breakdown': 1104,
#          'much': 16601,
#          'better': 13787,
#          'than': 29130,
#          'industry': 7782,
#          'average': 9331,
#          'miss': 6974,
#          'these': 14131,
#          'confirms': 411,
#          'you': 94326,
#          'will': 128206,
#          'see': 44345,
#          'violent': 147,
#          'move': 22530,
#          'downward': 831,
#          'my': 51362,
#          'base': 1468,
#          'gap': 9764,
#          'ma': 5061,
#          'cabot': 106,
#          'weekly': 7172,
#          'video': 2816,
#          'quot': 40091,
#          'resilient': 137,
#          'growth': 36093,
#          'when': 30042,
#          'wa': 55257,
#          'kid': 1697,
#          'froend': 1,
#          'told': 3842,
#          'me': 25922,
#          'moon': 2177,
#          'made': 7819,
#          'cheese': 116,
#          'percent': 6303,
#          'rank': 5337,
#          'th': 6560,
#          'percentile': 1399,
#          'thank': 4123,
#          'don': 25447,
#          'feel': 5989,
#          'or': 37499,
#          'do': 24611,
#          'well': 16550,
#          'they': 56357,
#          'already': 9658,
#          'during': 2561,
#          'youtube': 598,
#          'interview': 623,
#          'mitch': 62,
#          'couldn': 1252,
#          'remember': 4819,
#          'single': 2166,
#          'movie': 881,
#          'he': 11568,
#          'watched': 394,
#          'all': 59896,
#          'year': 34383,
#          'except': 1131,
#          'star': 2386,
#          'war': 4958,
#          'black': 1216,
#          'panther': 27,
#          'clothes': 115,
#          'downgrade': 4255,
#          'sale': 27059,
#          'interest': 11781,
#          'return': 7078,
#          'equity': 3276,
#          'although': 1869,
#          'market': 53676,
#          'up': 121582,
#          'doing': 5537,
#          'advanced': 992,
#          'a': 46191,
#          'info': 3817,
#          'july': 3147,
#          'be': 89282,
#          'most': 8235,
#          'normal': 1624,
#          'friday': 11161,
#          'contract': 14254,
#          'call': 67770,
#          'put': 36950,
#          'third': 1593,
#          'design': 609,
#          'win': 5867,
#          'timing': 658,
#          'match': 409,
#          'probably': 5059,
#          'arm': 307,
#          'alcohol': 72,
#          'tobacco': 149,
#          'firearm': 3,
#          'president': 2847,
#          'trump': 11808,
#          'tweet': 1397,
#          'spoke': 172,
#          'king': 1338,
#          'salman': 4,
#          'saudi': 757,
#          'arabia': 150,
#          'explained': 115,
#          'him': 2091,
#          'that': 89677,
#          'because': 7871,
#          'turmoil': 129,
#          'amp': 35686,
#          'today': 76250,
#          'insight': 8187,
#          'intc': 1984,
#          'mama': 166,
#          'said': 9403,
#          'ice': 375,
#          'cream': 115,
#          'finish': 1167,
#          'due': 3700,
#          'dil': 3,
#          'noticed': 365,
#          'last': 38612,
#          'jedi': 177,
#          'stream': 605,
#          'love': 10350,
#          'here': 74958,
#          'go': 52769,
#          'leave': 1353,
#          'view': 5128,
#          'look': 31200,
#          'ema': 1388,
#          'held': 2811,
#          'stochastics': 73,
#          'turning': 1167,
#          'spy': 2137,
#          'qqq': 655,
#          'opposite': 876,
#          'forward': 3415,
#          'pe': 4546,
#          'valuation': 4518,
#          'can': 44221,
#          'described': 346,
#          'cheap': 7837,
#          'saber': 13,
#          'capital': 2915,
#          'presentation': 626,
#          'common': 1432,
#          'denominator': 9,
#          'tencent': 164,
#          'facebook': 8707,
#          'google': 3214,
#          'how': 24453,
#          'one': 27507,
#          'performing': 859,
#          'crude': 489,
#          'petroleum': 249,
#          'natural': 517,
#          'gas': 1495,
#          'pu': 49,
#          'simply': 636,
#          'havent': 214,
#          'lost': 4552,
#          'any': 14394,
#          'brown': 256,
#          'run': 15786,
#          'tech': 9902,
#          'mf': 308,
#          'are': 101429,
#          'educated': 114,
#          'their': 24227,
#          'shit': 6413,
#          'every': 8941,
#          'former': 435,
#          'global': 2508,
#          'manufacturing': 363,
#          'pfizer': 452,
#          'independent': 150,
#          'director': 5452,
#          'nat': 136,
#          'ricciardi': 4,
#          'may': 10952,
#          'safest': 153,
#          'special': 627,
#          'limited': 553,
#          'offer': 1526,
#          'june': 1300,
#          'tradenet': 5,
#          'offering': 643,
#          'discount': 1455,
#          'intro': 49,
#          'program': 1011,
#          'below': 11232,
#          'financials': 989,
#          'summary': 464,
#          'jeff': 687,
#          'gundlach': 41,
#          'sohn': 23,
#          'long': 32569,
#          'thesis': 1005,
#          'energy': 2789,
#          'low': 23161,
#          'peg': 547,
#          'which': 8193,
#          'compensates': 296,
#          'indicates': 1981,
#          'rather': 2368,
#          'pres': 352,
#          'coming': 18932,
#          'seems': 5392,
#          'support': 16991,
#          'under': 8997,
#          'likely': 3646,
#          'bullshit': 875,
#          'worthless': 1025,
#          'mean': 6164,
#          'fucking': 2385,
#          'nothing': 7017,
#          'macau': 279,
#          'usa': 1071,
#          'take': 17635,
#          'let': 26926,
#          'where': 12422,
#          'right': 19054,
#          'now': 57539,
#          'ugly': 1842,
#          'without': 2339,
#          'clear': 2622,
#          'level': 9592,
#          'term': 17571,
#          'bearish': 11440,
#          'll': 13146,
#          'previously': 2035,
#          'mo': 893,
#          'followed': 973,
#          'end': 15778,
#          'another': 14004,
#          'runup': 188,
#          'dropped': 2955,
#          'smart': 3332,
#          'money': 24916,
#          'betting': 856,
#          'deal': 6723,
#          'update': 20555,
#          'technical': 11303,
#          'bad': 13243,
#          'doe': 11174,
#          'present': 2424,
#          'nice': 17346,
#          'opportunity': 5874,
#          'completely': 1017,
#          'scale': 382,
#          'time': 39416,
#          'gobble': 106,
#          'play': 9237,
#          'aka': 336,
#          'favorite': 870,
#          'them': 11059,
#          'iddy': 1,
#          'bitty': 10,
#          'kiddy': 33,
#          'hand': 3733,
#          'awesome': 1846,
#          'concerned': 541,
#          'eow': 2109,
#          'might': 8907,
#          'wk': 1305,
#          'throwback': 59,
#          'u': 13300,
#          'advisor': 220,
#          'upgrade': 6839,
#          'shorties': 808,
#          'dreaming': 232,
#          'depression': 139,
#          'somethin': 27,
#          'loll': 48,
#          'updated': 814,
#          'hormel': 115,
#          'food': 1482,
#          'dividend': 8463,
#          'analysis': 3391,
#          'consumer': 1989,
#          'defensive': 282,
#          'intel': 7968,
#          'profitability': 1887,
#          'safety': 1126,
#          'score': 2652,
#          'technology': 3125,
#          'both': 6238,
#          'positive': 9043,
#          'looking': 17934,
#          'mad': 1240,
#          'report': 55268,
#          'block': 9925,
#          'person': 698,
#          'spam': 272,
#          'should': 24027,
#          'open': 20695,
#          'projection': 280,
#          'thats': 2258,
#          'true': 2132,
#          'prefer': 361,
#          'from': 62396,
#          'turd': 1080,
#          'wal': 125,
#          'mart': 147,
#          'aristocrat': 302,
#          'valueinvesting': 53,
#          'dvb': 22,
#          'aaamp': 28,
#          'marriage': 38,
#          'bank': 7542,
#          'account': 2801,
#          'dm': 57,
#          'won': 5420,
#          'stop': 12796,
#          'posting': 1290,
#          'holding': 14810,
#          'big': 27633,
#          'calm': 907,
#          'down': 69368,
#          'luck': 3427,
#          'chase': 1362,
#          'continues': 2442,
#          'hopefully': 2618,
#          'catch': 1750,
#          'before': 25834,
#          'lisa': 3075,
#          'announces': 3374,
#          'rd': 1374,
#          'permamently': 1,
#          'turned': 1356,
#          'off': 21259,
#          'trading': 21192,
#          'maybe': 7823,
#          'altogether': 26,
#          'manipulation': 2484,
#          'very': 20008,
#          'rich': 1618,
#          'make': 19935,
#          'poor': 1889,
#          'fuk': 227,
#          'almost': 5592,
#          'pct': 747,
#          'buyback': 5102,
#          'got': 16215,
#          'share': 48702,
#          'though': 4117,
#          'drip': 324,
#          'dumped': 1063,
#          'obv': 181,
#          'but': 53512,
#          'jeez': 339,
#          'bit': 4450,
#          'done': 5483,
#          'bounce': 11619,
#          'heikin': 10,
#          'ashi': 12,
#          'candle': 3264,
#          'confirmation': 739,
#          'liking': 419,
#          'wife': 650,
#          'tree': 514,
#          'fiddy': 32,
#          'sure': 8301,
#          'piggy': 270,
#          'lot': 10025,
#          'coin': 405,
#          'spend': 805,
#          'candy': 113,
#          'microsoft': 1969,
#          'investor': 8430,
#          'aren': 1687,
#          'happy': 4356,
#          'royal': 433,
#          'canada': 1347,
#          'reiterates': 1333,
#          'outperform': 1850,
#          'loop': 286,
#          'raise': 5772,
#          'never': 9018,
#          'been': 19825,
#          'wrong': 5608,
#          'miracle': 311,
#          'period': 1162,
#          'bollinger': 1347,
#          'band': 1516,
#          'dare': 353,
#          'say': 16294,
#          'didn': 5922,
#          'guilty': 97,
#          'fudge': 66,
#          'hardly': 255,
#          'ever': 5634,
#          'informative': 33,
#          'comment': 2098,
#          'page': 564,
#          'broken': 1592,
#          'giving': 1778,
#          'endless': 233,
#          'buffering': 4,
#          'icon': 95,
#          'give': 7675,
#          'viral': 18,
#          'walk': 1117,
#          'away': 4801,
#          'highlight': 249,
#          'growing': 2233,
#          'democrat': 278,
#          'leaving': 872,
#          'party': 1707,
#          'epoch': 2,
#          'robert': 973,
#          'baird': 650,
#          'neutral': 3513,
#          'weed': 717,
#          'other': 8473,
#          'drug': 1313,
#          'guess': 5927,
#          'reasonable': 610,
#          'nike': 4005,
#          'winning': 2108,
#          'click': 886,
#          'booking': 824,
#          'app': 5948,
#          'native': 20,
#          'seamless': 10,
#          'lovalized': 1,
#          'transactable': 1,
#          'ap': 80,
#          'vitiello': 1,
#          'tapped': 126,
#          'acting': 770,
#          'reach': 1962,
#          'iconic': 63,
#          'brand': 1969,
#          'built': 445,
#          'mobile': 965,
#          'show': 9569,
#          'morning': 11342,
#          'heading': 2783,
#          'ath': 3145,
#          'acquisition': 1769,
#          'total': 6061,
#          'past': 8306,
#          'exit': 1473,
#          'zone': 1590,
#          'fantastic': 574,
#          'read': 3822,
#          'oil': 4761,
#          'tighten': 205,
#          'bbl': 150,
#          'getting': 12183,
#          'closer': 977,
#          'greatest': 421,
#          'yearly': 1241,
#          'performance': 2094,
#          'did': 12610,
#          'champion': 159,
#          'cashflow': 75,
#          'highyield': 23,
#          'telecommunication': 7,
#          'pretty': 4504,
#          'risky': 713,
#          'gamble': 832,
#          'either': 3236,
#          'plummet': 326,
#          'rally': 6210,
#          'stronger': 867,
#          'apple': 12830,
#          'talking': 2745,
#          'referring': 107,
#          'intelsat': 6,
#          'punish': 128,
#          'seller': 3017,
#          'warehouse': 88,
#          'sense': 2205,
#          'old': 3815,
#          'gather': 129,
#          'dust': 433,
#          'pc': 616,
#          'gamers': 213,
#          'crypto': 1745,
#          'miner': 169,
#          'gpu': 1306,
#          'enthusiast': 27,
#          'waiting': 7246,
#          'two': 5514,
#          'only': 19012,
#          'medium': 3271,
#          'decent': 2928,
#          'pattern': 6528,
#          'five': 740,
#          'baba': 546,
#          'ahhhhhhhhhhhhhhhhhhhhh': 1,
#          'raytheon': 176,
#          'industrials': 309,
#          'military': 308,
#          'trending': 1957,
#          'riiiiiiiiiich': 1,
#          'sooooon': 11,
#          'buuuuls': 1,
#          'looooove': 4,
#          'drunk': 207,
#          'doesn': 6277,
#          'through': 6157,
#          'gapping': 285,
#          'warbey': 1,
#          'parker': 205,
#          'prep': 102,
#          'glass': 296,
#          'seen': 3833,
#          'focus': 1057,
#          'fashion': 212,
#          'wrt': 16,
#          'wearable': 106,
#          'like': 51922,
#          'sbux': 227,
#          'paying': 1526,
#          'full': 2984,
#          'sex': 171,
#          'change': 5184,
#          'employee': 1101,
#          'hit': 12524,
#          'bottom': 9698,
#          'line': 7064,
#          'recap': 1344,
#          'since': 22612,
#          'post': 7910,
#          'trade': 49537,
#          'included': 375,
#          'hsy': 25,
#          'uri': 46,
#          'sonc': 11,
#          'dri': 41,
#          'kmx': 32,
#          'wynn': 506,
#          'akam': 48,
#          'enterprise': 1330,
#          'value': 5684,
#          'v': 5400,
#          'cap': 4060,
#          'difference': 602,
#          'actual': 649,
#          'asset': 1905,
#          'spread': 2455,
#          'way': 16482,
#          'undervalued': 2519,
#          'million': 6353,
#          'added': 5564,
#          'dont': 6263,
#          'become': 1583,
#          'such': 2917,
#          'monopoly': 326,
#          'dipping': 306,
#          'into': 17280,
#          'everything': 4297,
#          'airline': 944,
#          'possibility': 469,
#          'loss': 7745,
#          'suggested': 321,
#          'chartmill': 199,
#          'analyzer': 520,
#          'resistance': 7073,
#          'len': 58,
#          'reversal': 4918,
#          'progress': 565,
#          've': 6742,
#          'recently': 828,
#          'closed': 3355,
#          'list': 3255,
#          'bought': 19135,
#          'same': 12092,
#          'used': 1744,
#          'according': 2034,
#          'data': 9735,
#          'reported': 14152,
#          'finra': 2763,
#          'clocked': 707,
#          'official': 472,
#          'came': 1631,
#          'saying': 4024,
#          'agree': 1544,
#          'resume': 516,
#          'cover': 5879,
#          'penis': 47,
#          'putang': 1,
#          'front': 570,
#          'leg': 2240,
#          'would': 22411,
#          'some': 30472,
#          'am': 14387,
#          'watching': 5571,
#          'wonder': 2999,
#          'valued': 1624,
#          'inning': 69,
#          'higher': 25481,
#          'also': 7917,
#          'shorted': 2973,
#          'consolidation': 2030,
#          'cautious': 516,
#          'stunned': 42,
#          'deeply': 92,
#          'disappointed': 457,
#          'close': 29517,
#          'ending': 1214,
#          'killed': 1221,
#          'best': 9984,
#          'february': 375,
#          'funny': 2522,
#          'thing': 12606,
#          'similar': 1136,
#          'story': 2654,
#          'different': 1559,
#          'crab': 39,
#          'measured': 489,
#          'divergence': 774,
#          'really': 11288,
#          'momentum': 3392,
#          'starting': 3250,
#          'shi': 59,
#          'venture': 299,
#          'tariff': 8068,
#          'increase': 3983,
#          'profit': 16094,
#          'recession': 1042,
#          'come': 18482,
#          'keep': 14980,
#          'buying': 23827,
#          'pure': 933,
#          'beanscreen': 2,
#          'min': 5729,
#          'indicating': 431,
#          'accumulation': 732,
#          'eod': 5174,
#          'could': 16217,
#          'pop': 7583,
#          'heavy': 1715,
#          'apog': 7,
#          'acn': 46,
#          'camp': 62,
#          'gi': 61,
#          'payx': 23,
#          'fdx': 113,
#          'goo': 179,
#          'squeeze': 5687,
#          'pullback': 4543,
#          'upside': 5176,
#          'nvda': 3196,
#          'safe': 1991,
#          'yield': 2523,
#          'div': 2205,
#          'adding': 2957,
#          'gladly': 91,
#          'irrationality': 24,
#          'reign': 40,
#          'possible': 4173,
#          'excess': 66,
#          'gain': 11678,
#          'welcome': 1341,
#          'gl': 3047,
#          'seeing': 2562,
#          'jumping': 707,
#          'joy': 272,
#          'least': 5521,
#          'given': 2986,
#          'action': 6834,
#          'bouncing': 948,
#          'continuation': 584,
#          'hopeful': 168,
#          'science': 334,
#          'officially': 540,
#          'became': 318,
#          'major': 3733,
#          'university': 70,
#          'ai': 1731,
#          'brainers': 5,
#          'era': 294,
#          'second': 3447,
#          'minute': 5133,
#          'rule': 2004,
#          'applies': 83,
#          'zbra': 6,
#          'six': 557,
#          'fc': 23,
#          'gbx': 4,
#          'fds': 31,
#          'avav': 9,
#          'killing': 1666,
#          'tax': 2252,
#          'cut': 4888,
#          'idea': 3828,
#          'haven': 1829,
#          'posted': 4218,
#          'while': 7227,
#          'omg': 1698,
#          'toy': 360,
#          'land': 607,
#          'amazing': 3002,
#          'contributed': 38,
#          'ytd': 1173,
#          'popular': 406,
#          'word': 2041,
#          'buyin': 130,
#          'those': 9853,
#          'dip': 17732,
#          'haha': 2082,
#          'makin': 55,
#          'rain': 218,
#          'white': 924,
#          'house': 1699,
#          'quality': 1462,
#          'moment': 2631,
#          'doubt': 1738,
#          'production': 937,
#          'eps': 33292,
#          'constellation': 327,
#          'disney': 1297,
#          'clinch': 9,
#          'acquire': 712,
#          'fox': 768,
#          'group': 4422,
#          'counter': 250,
#          'aggregate': 761,
#          'southwest': 152,
#          'flight': 328,
#          'dallas': 44,
#          'delta': 422,
#          'spat': 52,
#          'california': 290,
#          'netflix': 5120,
#          'inc': 7035,
#          'nflx': 3252,
#          'versus': 926,
#          'fb': 7815,
#          'starbucks': 593,
#          'using': 2148,
#          'iex': 2187,
#          'calculate': 207,
#          'shorters': 271,
#          'emergence': 1,
#          'bankruptcy': 1423,
#          'emergency': 85,
#          'zwj': 6,
#          'investment': 4289,
#          'counsel': 371,
#          'lower': 16061,
#          'stake': 1025,
#          'unitedhealth': 172,
#          'unh': 107,
#          'tyzen': 1,
#          'vega': 682,
#          'laptop': 368,
#          'investing': 1688,
#          'annuity': 17,
#          'yr': 2894,
#          'bond': 1263,
#          'continue': 3691,
#          'add': 6076,
#          'unsure': 70,
#          'country': 1033,
#          'amd': 22535,
#          'ryzen': 1003,
#          'gettin': 151,
#          'blasted': 70,
#          'cgnx': 6,
#          'cx': 28,
#          'aaoi': 53,
#          'aa': 75,
#          'amswa': 1,
#          'yy': 20,
#          'snx': 8,
#          'shark': 219,
#          'definitely': 1899,
#          'august': 2665,
#          'g': 1228,
#          'point': 8711,
#          'huge': 9307,
#          'closing': 3857,
#          'scalp': 1291,
#          'giant': 1405,
#          'fermenting': 1,
#          'marked': 88,
#          'compared': 2780,
#          'book': 1963,
#          'cheaply': 737,
#          'quite': 3393,
#          'job': 3568,
#          'started': 5092,
#          'clearly': 1056,
#          'cup': 1974,
#          'holder': 2398,
#          'inverse': 505,
#          'confidence': 771,
#          'debt': 3076,
#          'sell': 35151,
#          'interesting': 3532,
#          'frame': 436,
#          'trader': 4878,
#          'meanwhile': 505,
#          'galaxy': 121,
#          'far': 5527,
#          'broadening': 29,
#          'wedge': 1253,
#          'descending': 312,
#          'large': 6258,
#          'im': 5083,
#          'pt': 16021,
#          'three': 1642,
#          'falling': 3279,
#          'peak': 1897,
#          'fourth': 250,
#          'everyone': 8409,
#          'coke': 281,
#          'smile': 213,
#          'thanks': 5687,
#          'selling': 17609,
#          'prove': 454,
#          'terrible': 937,
#          'error': 161,
#          'article': 2513,
#          'hint': 345,
#          'sogou': 11,
#          'finger': 680,
#          'crossed': 1344,
#          'triple': 1168,
#          'top': 14099,
#          'bro': 615,
#          'work': 5148,
#          'delete': 293,
#          'blue': 1664,
#          'arrow': 118,
#          'your': 25511,
#          'delusion': 82,
#          'overbought': 1692,
#          'changing': 490,
#          'mr': 1179,
#          'yo': 895,
#          'hi': 794,
#          'bed': 715,
#          'night': 2769,
#          'prepared': 346,
#          'policy': 364,
#          ...})

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the number of messages. Then remove words that only appear in some small fraction of the messages.

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = {word: count/len(stacked) for word, count in bow.items()}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 1e-5

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 15

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = [word[0] for word in bow.most_common(high_cutoff)]


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# ['the', 'to', 'is', 'for', 'on', 'of', 'and', 'in', 'this', 'it', 'at', 'will', 'up', 'are', 'you']
# 4512

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
filtered_words
# Out:
# ['great',
#  'buy',
#  'ill',
#  'wait',
#  'staanalystalert',
#  'jefferies',
#  'maintains',
#  'with',
#  'rating',
#  'hold',
#  'setting',
#  'target',
#  'price',
#  'usd',
#  'our',
#  'own',
#  'verdict',
#  'heard',
#  'there',
#  'guy',
#  'who',
#  'know',
#  'someone',
#  'think',
#  'somebody',
#  'something',
#  'stocktwits',
#  'reveal',
#  'yourself',
#  'why',
#  'drop',
#  'warren',
#  'buffet',
#  'taking',
#  'out',
#  'his',
#  'position',
#  'bear',
#  'have',
#  'reason',
#  'pay',
#  'more',
#  'attention',
#  'ok',
#  'good',
#  'we',
#  're',
#  'not',
#  'dropping',
#  'over',
#  'weekend',
#  'lol',
#  'daily',
#  'chart',
#  'need',
#  'get',
#  'back',
#  'above',
#  'per',
#  'week',
#  'after',
#  'spike',
#  'if',
#  'no',
#  'news',
#  'month',
#  'bo',
#  'then',
#  'bingo',
#  'what',
#  'odds',
#  'strong',
#  'short',
#  'ratio',
#  'float',
#  'via',
#  'squeezing',
#  'perfect',
#  'place',
#  'an',
#  'option',
#  'straddle',
#  'near',
#  'supporting',
#  'trend',
#  'start',
#  'new',
#  'monday',
#  'expect',
#  'volume',
#  'across',
#  'key',
#  'company',
#  'sector',
#  'breakout',
#  'strategy',
#  'current',
#  'portfolio',
#  'bull',
#  'catalyst',
#  'continuing',
#  'uptrend',
#  'pill',
#  'pack',
#  'amazon',
#  'prime',
#  'day',
#  'earnings',
#  'test',
#  'break',
#  'soon',
#  'ha',
#  'moved',
#  'check',
#  'movement',
#  'peer',
#  'mkm',
#  'partner',
#  'set',
#  'too',
#  'early',
#  'tell',
#  'going',
#  'happen',
#  'even',
#  'about',
#  'still',
#  'so',
#  'many',
#  'financially',
#  'healthy',
#  'problem',
#  'meeting',
#  'obligation',
#  'bullish',
#  'stock',
#  'watch',
#  'setup',
#  'blog',
#  'by',
#  'just',
#  'high',
#  'alert',
#  'next',
#  'gt',
#  'breakdown',
#  'much',
#  'better',
#  'than',
#  'industry',
#  'average',
#  'miss',
#  'these',
#  'confirms',
#  'see',
#  'move',
#  'downward',
#  'my',
#  'base',
#  'gap',
#  'ma',
#  'weekly',
#  'video',
#  'quot',
#  'growth',
#  'when',
#  'wa',
#  'kid',
#  'told',
#  'me',
#  'moon',
#  'made',
#  'percent',
#  'rank',
#  'th',
#  'percentile',
#  'thank',
#  'don',
#  'feel',
#  'or',
#  'do',
#  'well',
#  'they',
#  'already',
#  'during',
#  'youtube',
#  'interview',
#  'couldn',
#  'remember',
#  'single',
#  'movie',
#  'he',
#  'watched',
#  'all',
#  'year',
#  'except',
#  'star',
#  'war',
#  'black',
#  'downgrade',
#  'sale',
#  'interest',
#  'return',
#  'equity',
#  'although',
#  'market',
#  'doing',
#  'advanced',
#  'a',
#  'info',
#  'july',
#  'be',
#  'most',
#  'normal',
#  'friday',
#  'contract',
#  'call',
#  'put',
#  'third',
#  'design',
#  'win',
#  'timing',
#  'match',
#  'probably',
#  'arm',
#  'president',
#  'trump',
#  'tweet',
#  'spoke',
#  'king',
#  'saudi',
#  'him',
#  'that',
#  'because',
#  'amp',
#  'today',
#  'insight',
#  'intc',
#  'mama',
#  'said',
#  'ice',
#  'finish',
#  'due',
#  'noticed',
#  'last',
#  'jedi',
#  'stream',
#  'love',
#  'here',
#  'go',
#  'leave',
#  'view',
#  'look',
#  'ema',
#  'held',
#  'turning',
#  'spy',
#  'qqq',
#  'opposite',
#  'forward',
#  'pe',
#  'valuation',
#  'can',
#  'described',
#  'cheap',
#  'capital',
#  'presentation',
#  'common',
#  'tencent',
#  'facebook',
#  'google',
#  'how',
#  'one',
#  'performing',
#  'crude',
#  'petroleum',
#  'natural',
#  'gas',
#  'simply',
#  'havent',
#  'lost',
#  'any',
#  'brown',
#  'run',
#  'tech',
#  'mf',
#  'their',
#  'shit',
#  'every',
#  'former',
#  'global',
#  'manufacturing',
#  'pfizer',
#  'director',
#  'may',
#  'special',
#  'limited',
#  'offer',
#  'june',
#  'offering',
#  'discount',
#  'program',
#  'below',
#  'financials',
#  'summary',
#  'jeff',
#  'long',
#  'thesis',
#  'energy',
#  'low',
#  'peg',
#  'which',
#  'compensates',
#  'indicates',
#  'rather',
#  'pres',
#  'coming',
#  'seems',
#  'support',
#  'under',
#  'likely',
#  'bullshit',
#  'worthless',
#  'mean',
#  'fucking',
#  'nothing',
#  'macau',
#  'usa',
#  'take',
#  'let',
#  'where',
#  'right',
#  'now',
#  'ugly',
#  'without',
#  'clear',
#  'level',
#  'term',
#  'bearish',
#  'll',
#  'previously',
#  'mo',
#  'followed',
#  'end',
#  'another',
#  'runup',
#  'dropped',
#  'smart',
#  'money',
#  'betting',
#  'deal',
#  'update',
#  'technical',
#  'bad',
#  'doe',
#  'present',
#  'nice',
#  'opportunity',
#  'completely',
#  'scale',
#  'time',
#  'play',
#  'aka',
#  'favorite',
#  'them',
#  'hand',
#  'awesome',
#  'concerned',
#  'eow',
#  'might',
#  'wk',
#  'u',
#  'advisor',
#  'upgrade',
#  'shorties',
#  'dreaming',
#  'updated',
#  'food',
#  'dividend',
#  'analysis',
#  'consumer',
#  'defensive',
#  'intel',
#  'profitability',
#  'safety',
#  'score',
#  'technology',
#  'both',
#  'positive',
#  'looking',
#  'mad',
#  'report',
#  'block',
#  'person',
#  'spam',
#  'should',
#  'open',
#  'projection',
#  'thats',
#  'true',
#  'prefer',
#  'from',
#  'turd',
#  'aristocrat',
#  'bank',
#  'account',
#  'won',
#  'stop',
#  'posting',
#  'holding',
#  'big',
#  'calm',
#  'down',
#  'luck',
#  'chase',
#  'continues',
#  'hopefully',
#  'catch',
#  'before',
#  'lisa',
#  'announces',
#  'rd',
#  'turned',
#  'off',
#  'trading',
#  'maybe',
#  'manipulation',
#  'very',
#  'rich',
#  'make',
#  'poor',
#  'fuk',
#  'almost',
#  'pct',
#  'buyback',
#  'got',
#  'share',
#  'though',
#  'drip',
#  'dumped',
#  'obv',
#  'but',
#  'jeez',
#  'bit',
#  'done',
#  'bounce',
#  'candle',
#  'confirmation',
#  'liking',
#  'wife',
#  'tree',
#  'sure',
#  'piggy',
#  'lot',
#  'coin',
#  'spend',
#  'microsoft',
#  'investor',
#  'aren',
#  'happy',
#  'royal',
#  'canada',
#  'reiterates',
#  'outperform',
#  'loop',
#  'raise',
#  'never',
#  'been',
#  'wrong',
#  'miracle',
#  'period',
#  'bollinger',
#  'band',
#  'dare',
#  'say',
#  'didn',
#  'hardly',
#  'ever',
#  'comment',
#  'page',
#  'broken',
#  'giving',
#  'endless',
#  'give',
#  'walk',
#  'away',
#  'highlight',
#  'growing',
#  'democrat',
#  'leaving',
#  'party',
#  'robert',
#  'baird',
#  'neutral',
#  'weed',
#  'other',
#  'drug',
#  'guess',
#  'reasonable',
#  'nike',
#  'winning',
#  'click',
#  'booking',
#  'app',
#  'acting',
#  'reach',
#  'brand',
#  'built',
#  'mobile',
#  'show',
#  'morning',
#  'heading',
#  'ath',
#  'acquisition',
#  'total',
#  'past',
#  'exit',
#  'zone',
#  'fantastic',
#  'read',
#  'oil',
#  'tighten',
#  'getting',
#  'closer',
#  'greatest',
#  'yearly',
#  'performance',
#  'did',
#  'champion',
#  'pretty',
#  'risky',
#  'gamble',
#  'either',
#  'plummet',
#  'rally',
#  'stronger',
#  'apple',
#  'talking',
#  'seller',
#  'sense',
#  'old',
#  'dust',
#  'pc',
#  'gamers',
#  'crypto',
#  'miner',
#  'gpu',
#  'waiting',
#  'two',
#  'only',
#  'medium',
#  'decent',
#  'pattern',
#  'five',
#  'baba',
#  'raytheon',
#  'industrials',
#  'military',
#  'trending',
#  'drunk',
#  'doesn',
#  'through',
#  'gapping',
#  'parker',
#  'glass',
#  'seen',
#  'focus',
#  'fashion',
#  'like',
#  'sbux',
#  'paying',
#  'full',
#  'sex',
#  'change',
#  'employee',
#  'hit',
#  'bottom',
#  'line',
#  'recap',
#  'since',
#  'post',
#  'trade',
#  'included',
#  'wynn',
#  'enterprise',
#  'value',
#  'v',
#  'cap',
#  'difference',
#  'actual',
#  'asset',
#  'spread',
#  'way',
#  'undervalued',
#  'million',
#  'added',
#  'dont',
#  'become',
#  'such',
#  'monopoly',
#  'dipping',
#  'into',
#  'everything',
#  'airline',
#  'possibility',
#  'loss',
#  'suggested',
#  'chartmill',
#  'analyzer',
#  'resistance',
#  'reversal',
#  'progress',
#  've',
#  'recently',
#  'closed',
#  'list',
#  'bought',
#  'same',
#  'used',
#  'according',
#  'data',
#  'reported',
#  'finra',
#  'clocked',
#  'official',
#  'came',
#  'saying',
#  'agree',
#  'resume',
#  'cover',
#  'front',
#  'leg',
#  'would',
#  'some',
#  'am',
#  'watching',
#  'wonder',
#  'valued',
#  'higher',
#  'also',
#  'shorted',
#  'consolidation',
#  'cautious',
#  'disappointed',
#  'close',
#  'ending',
#  'killed',
#  'best',
#  'february',
#  'funny',
#  'thing',
#  'similar',
#  'story',
#  'different',
#  'measured',
#  'divergence',
#  'really',
#  'momentum',
#  'starting',
#  'venture',
#  'tariff',
#  'increase',
#  'profit',
#  'recession',
#  'come',
#  'keep',
#  'buying',
#  'pure',
#  'min',
#  'indicating',
#  'accumulation',
#  'eod',
#  'could',
#  'pop',
#  'heavy',
#  'goo',
#  'squeeze',
#  'pullback',
#  'upside',
#  'nvda',
#  'safe',
#  'yield',
#  'div',
#  'adding',
#  'possible',
#  'gain',
#  'welcome',
#  'gl',
#  'seeing',
#  'jumping',
#  'joy',
#  'least',
#  'given',
#  'action',
#  'bouncing',
#  'continuation',
#  'hopeful',
#  'science',
#  'officially',
#  'became',
#  'major',
#  'ai',
#  'era',
#  'second',
#  'minute',
#  'rule',
#  'six',
#  'killing',
#  'tax',
#  'cut',
#  'idea',
#  'haven',
#  'posted',
#  'while',
#  'omg',
#  'toy',
#  'land',
#  'amazing',
#  'ytd',
#  'popular',
#  'word',
#  'those',
#  'dip',
#  'haha',
#  'rain',
#  'white',
#  'house',
#  'quality',
#  'moment',
#  'doubt',
#  'production',
#  'eps',
#  'constellation',
#  'disney',
#  'acquire',
#  'fox',
#  'group',
#  'counter',
#  'aggregate',
#  'flight',
#  'delta',
#  'california',
#  'netflix',
#  'inc',
#  'nflx',
#  'versus',
#  'fb',
#  'starbucks',
#  'using',
#  'iex',
#  'calculate',
#  'shorters',
#  'bankruptcy',
#  'investment',
#  'counsel',
#  'lower',
#  'stake',
#  'unitedhealth',
#  'vega',
#  'laptop',
#  'investing',
#  'yr',
#  'bond',
#  'continue',
#  'add',
#  'country',
#  'amd',
#  'ryzen',
#  'shark',
#  'definitely',
#  'august',
#  'g',
#  'point',
#  'huge',
#  'closing',
#  'scalp',
#  'giant',
#  'compared',
#  'book',
#  'cheaply',
#  'quite',
#  'job',
#  'started',
#  'clearly',
#  'cup',
#  'holder',
#  'inverse',
#  'confidence',
#  'debt',
#  'sell',
#  'interesting',
#  'frame',
#  'trader',
#  'meanwhile',
#  'far',
#  'wedge',
#  'descending',
#  'large',
#  'im',
#  'pt',
#  'three',
#  'falling',
#  'peak',
#  'fourth',
#  'everyone',
#  'coke',
#  'smile',
#  'thanks',
#  'selling',
#  'prove',
#  'terrible',
#  'error',
#  'article',
#  'hint',
#  'finger',
#  'crossed',
#  'triple',
#  'top',
#  'bro',
#  'work',
#  'delete',
#  'blue',
#  'your',
#  'overbought',
#  'changing',
#  'mr',
#  'yo',
#  'hi',
#  'bed',
#  'night',
#  'prepared',
#  'policy',
#  'store',
#  'product',
#  'fyi',
#  'ramp',
#  'worker',
#  'hill',
#  'people',
#  'manager',
#  'city',
#  'fail',
#  'despite',
#  'bb',
#  'thinking',
#  'mm',
#  'driving',
#  'prior',
#  'argument',
#  'sound',
#  'becoming',
#  'loses',
#  'gaming',
#  'channel',
#  'cash',
#  'machine',
#  'semi',
#  'altria',
#  'graph',
#  'reached',
#  'want',
#  'steady',
#  'amid',
#  'weak',
#  'demand',
#  'display',
#  'leak',
#  'screen',
#  'surface',
#  'device',
#  'fit',
#  'pocket',
#  'piotroski',
#  'health',
#  'original',
#  'having',
#  'competitive',
#  'server',
#  'around',
#  'epyc',
#  'ball',
#  'security',
#  'flaw',
#  'nm',
#  'fire',
#  'ceo',
#  'sh',
#  'wowza',
#  'ago',
#  'real',
#  'boom',
#  'social',
#  'bigger',
#  'christmas',
#  'celgene',
#  'sigh',
#  'relief',
#  'success',
#  'mistake',
#  'cry',
#  'everyday',
#  'roa',
#  'outperforms',
#  'longer',
#  'sheep',
#  'racist',
#  'happening',
#  'ease',
#  'def',
#  'horrible',
#  'spotify',
#  'content',
#  'positioning',
#  'underweight',
#  'crowdthnk',
#  'algo',
#  'forecast',
#  'chance',
#  'moving',
#  'brainer',
#  'dog',
#  'mu',
#  'serious',
#  'net',
#  'negative',
#  'indicator',
#  'opinion',
#  'brexit',
#  'banker',
#  'risk',
#  'life',
#  'edge',
#  'fill',
#  'history',
#  'inside',
#  'curve',
#  'face',
#  'fed',
#  'concern',
#  'study',
#  'watchlist',
#  'invest',
#  'wallstreet',
#  'runner',
#  'pull',
#  'slow',
#  'thought',
#  'flush',
#  'china',
#  'attack',
#  'rated',
#  'median',
#  'trust',
#  'anticipation',
#  'rising',
#  'analyst',
#  'sorry',
#  'predicted',
#  'exited',
#  'worth',
#  'weight',
#  'little',
#  'announce',
#  'boeing',
#  'baked',
#  'deep',
#  'fails',
#  'again',
#  'making',
#  'baby',
#  'date',
#  'extremely',
#  'within',
#  'midterm',
#  'slightly',
#  'stupid',
#  'wasting',
#  'oversold',
#  'thursday',
#  'breaking',
#  'pharmaceutical',
#  'field',
#  'retest',
#  'quickly',
#  'world',
#  'holiday',
#  'thurs',
#  'expensive',
#  'strongly',
#  'part',
#  'selection',
#  'benefit',
#  'buyer',
#  'fri',
#  'pinned',
#  'com',
#  'amzn',
#  'weakness',
#  'angle',
#  'crazy',
#  ...]

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = {word: i for i, word in enumerate(filtered_words,1)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = {i: word for i, word in enumerate(filtered_words)}
# tokenized with the words not in `filtered_words` removed.
filtered = [ [t for t in tok if t in vocab] for tok in tokenized ]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.19390706951030703

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout

        # Setup embedding layer
        self.embedding = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embed_size)
        
        # Setup additional layers
        self.lstm = nn.LSTM(input_size=embed_size, 
                            hidden_size=lstm_size,
                            num_layers=lstm_layers, 
                            batch_first=False, 
                            dropout=self.dropout)
        
        self.dropout = nn.Dropout(dropout)
        
        self.fc = nn.Linear(in_features=lstm_size, out_features=output_size)
        self.logsoftmax = nn.LogSoftmax(dim=1)


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data 
 
        if False: #torch.cuda.isavailable():
            hidden = (weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_().cuda(),
                      weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_().cuda())
        else:
            hidden = (weight.new(self.lstm_layers,batch_size, self.lstm_size).zero_(),
                      weight.new(self.lstm_layers,batch_size, self.lstm_size).zero_())
        return hidden


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        embed = self.embedding (nn_input)
        lstm_out, hidden_state = self.lstm(embed, hidden_state)
        lstm_out = lstm_out[-1]
        
        #lstm_output = lstm_out.contiguous().view(-1, self.lstm_size)
        
        logps = self.logsoftmax(self.dropout(self.fc(lstm_out)))
        
        return logps, hidden_state

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, lstm_layers=2, dropout=0.1)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.7857, -1.5839, -1.4615, -1.4920, -1.7701],
#         [-1.9904, -1.6936, -1.3797, -1.4070, -1.6984],
#         [-2.0395, -1.5436, -1.4119, -1.4322, -1.7496],
#         [-1.9838, -1.4793, -1.3478, -1.6727, -1.6761]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   
split=0.8
valid_split = int(len(token_ids) * split)

train_features = token_ids[:valid_split]
valid_features = token_ids[valid_split:]
train_labels = sentiments[:valid_split]
valid_labels = sentiments[valid_split:]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
model.embedding.weight.data.uniform_(-1, 1)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(4513, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (logsoftmax): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

epochs = 5
batch_size = 512
learning_rate = 0.001
sequence_length = 20

print_every = 100
clip = 5
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    hidden = model.init_hidden(batch_size=batch_size)
      
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=sequence_length, shuffle=True):
        if text_batch.size()!=torch.Size([sequence_length,batch_size]):
            continue
        steps += 1
        hidden = tuple([each.data for each in hidden])
        
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        model.zero_grad()

        # get the output from the model
        logps, hidden = model(text_batch, hidden)
        #print(logps.squeeze().view(real_batch_size,-1).shape)
        #print(logps.squeeze().shape)
        # calculate the loss and perform backprop
        loss = criterion(logps, labels)
        loss.backward()
        
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        if clip:
            nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()
        
        if steps % print_every == 0:
            model.eval()
            
            num_correct = 0
            
            # Get validation loss
            val_losses = []
            for text_batch, labels in dataloader(
                    valid_features, valid_labels, batch_size=batch_size, 
                    sequence_length=sequence_length, shuffle=False):

                real_batch_size = min(batch_size, text_batch.size(1))
                val_h = model.init_hidden(real_batch_size)

                text_batch, labels = text_batch.to(device), labels.to(device)
                for each in val_h:
                    each.to(device)

                #print(text_batch.size())
                logps, val_h = model(text_batch, val_h)
                val_loss = criterion(logps, labels)
                val_losses.append(val_loss.item())

                # convert output probabilities to predicted class (0 or 4)
                pred = torch.argmax(torch.exp(logps), dim=-1)

                # compare predictions to true label
                correct_tensor = pred.eq(labels.view_as(pred))
                correct = np.squeeze(correct_tensor.numpy()) if device.type=='cpu' \
                     else np.squeeze(correct_tensor.cpu().numpy())
                num_correct += np.sum(correct)

            val_acc = num_correct / len(valid_labels)
            
            print("Epoch: {}/{}...".format(epoch+1, epochs),
                  "Step: {}...".format(steps),
                  "Loss: {:.6f}...".format(loss.item()),
                  "Val Loss: {:.6f}".format(np.mean(val_losses)),
                  "Val Accuracy: {:.3f}".format(val_acc))
            
            model.train()
# Out:
# Starting epoch 1
# Epoch: 1/5... Step: 100... Loss: 0.989051... Val Loss: 0.928807 Val Accuracy: 0.639
# Epoch: 1/5... Step: 200... Loss: 0.938604... Val Loss: 0.887284 Val Accuracy: 0.656
# Epoch: 1/5... Step: 300... Loss: 0.915647... Val Loss: 0.844604 Val Accuracy: 0.677
# Epoch: 1/5... Step: 400... Loss: 0.886740... Val Loss: 0.818843 Val Accuracy: 0.687
# Epoch: 1/5... Step: 500... Loss: 0.977739... Val Loss: 0.805580 Val Accuracy: 0.691
# Epoch: 1/5... Step: 600... Loss: 0.801978... Val Loss: 0.786848 Val Accuracy: 0.700
# Epoch: 1/5... Step: 700... Loss: 0.940728... Val Loss: 0.780773 Val Accuracy: 0.703
# Epoch: 1/5... Step: 800... Loss: 0.901220... Val Loss: 0.767726 Val Accuracy: 0.707
# Epoch: 1/5... Step: 900... Loss: 0.921006... Val Loss: 0.768056 Val Accuracy: 0.707
# Epoch: 1/5... Step: 1000... Loss: 0.802121... Val Loss: 0.759103 Val Accuracy: 0.713
# Epoch: 1/5... Step: 1100... Loss: 0.764829... Val Loss: 0.756386 Val Accuracy: 0.712
# Epoch: 1/5... Step: 1200... Loss: 0.750083... Val Loss: 0.751174 Val Accuracy: 0.714
# Epoch: 1/5... Step: 1300... Loss: 0.886587... Val Loss: 0.746878 Val Accuracy: 0.717
# Epoch: 1/5... Step: 1400... Loss: 0.786266... Val Loss: 0.745648 Val Accuracy: 0.716
# Epoch: 1/5... Step: 1500... Loss: 0.892894... Val Loss: 0.739584 Val Accuracy: 0.719
# Epoch: 1/5... Step: 1600... Loss: 0.835029... Val Loss: 0.742181 Val Accuracy: 0.719
# Starting epoch 2
# Epoch: 2/5... Step: 100... Loss: 0.812668... Val Loss: 0.743493 Val Accuracy: 0.714
# Epoch: 2/5... Step: 200... Loss: 0.798685... Val Loss: 0.734702 Val Accuracy: 0.721
# Epoch: 2/5... Step: 300... Loss: 0.773169... Val Loss: 0.740401 Val Accuracy: 0.718
# Epoch: 2/5... Step: 400... Loss: 0.740775... Val Loss: 0.735569 Val Accuracy: 0.721
# Epoch: 2/5... Step: 500... Loss: 0.817117... Val Loss: 0.730923 Val Accuracy: 0.722
# Epoch: 2/5... Step: 600... Loss: 0.771343... Val Loss: 0.732660 Val Accuracy: 0.720
# Epoch: 2/5... Step: 700... Loss: 0.827549... Val Loss: 0.732713 Val Accuracy: 0.721
# Epoch: 2/5... Step: 800... Loss: 0.780196... Val Loss: 0.727370 Val Accuracy: 0.724
# Epoch: 2/5... Step: 900... Loss: 0.817065... Val Loss: 0.727534 Val Accuracy: 0.723
# Epoch: 2/5... Step: 1000... Loss: 0.733993... Val Loss: 0.729582 Val Accuracy: 0.722
# Epoch: 2/5... Step: 1100... Loss: 0.868870... Val Loss: 0.727000 Val Accuracy: 0.725
# Epoch: 2/5... Step: 1200... Loss: 0.780043... Val Loss: 0.721966 Val Accuracy: 0.724
# Epoch: 2/5... Step: 1300... Loss: 0.824888... Val Loss: 0.726710 Val Accuracy: 0.722
# Epoch: 2/5... Step: 1400... Loss: 0.841091... Val Loss: 0.724561 Val Accuracy: 0.723
# Epoch: 2/5... Step: 1500... Loss: 0.788549... Val Loss: 0.722526 Val Accuracy: 0.725
# Epoch: 2/5... Step: 1600... Loss: 0.750824... Val Loss: 0.719889 Val Accuracy: 0.724
# Starting epoch 3
# Epoch: 3/5... Step: 100... Loss: 0.748603... Val Loss: 0.730647 Val Accuracy: 0.724
# Epoch: 3/5... Step: 200... Loss: 0.715098... Val Loss: 0.739180 Val Accuracy: 0.721
# Epoch: 3/5... Step: 300... Loss: 0.727861... Val Loss: 0.735720 Val Accuracy: 0.721
# Epoch: 3/5... Step: 400... Loss: 0.747768... Val Loss: 0.738622 Val Accuracy: 0.720
# Epoch: 3/5... Step: 500... Loss: 0.780509... Val Loss: 0.740591 Val Accuracy: 0.722
# Epoch: 3/5... Step: 600... Loss: 0.725284... Val Loss: 0.734404 Val Accuracy: 0.720
# Epoch: 3/5... Step: 700... Loss: 0.795686... Val Loss: 0.736661 Val Accuracy: 0.721
# Epoch: 3/5... Step: 800... Loss: 0.810078... Val Loss: 0.741995 Val Accuracy: 0.722
# Epoch: 3/5... Step: 900... Loss: 0.754961... Val Loss: 0.732959 Val Accuracy: 0.724
# Epoch: 3/5... Step: 1000... Loss: 0.742194... Val Loss: 0.732567 Val Accuracy: 0.722
# Epoch: 3/5... Step: 1100... Loss: 0.678297... Val Loss: 0.734961 Val Accuracy: 0.721
# Epoch: 3/5... Step: 1200... Loss: 0.724301... Val Loss: 0.730282 Val Accuracy: 0.725
# Epoch: 3/5... Step: 1300... Loss: 0.843578... Val Loss: 0.725756 Val Accuracy: 0.727
# Epoch: 3/5... Step: 1400... Loss: 0.753638... Val Loss: 0.726091 Val Accuracy: 0.724
# Epoch: 3/5... Step: 1500... Loss: 0.797546... Val Loss: 0.725960 Val Accuracy: 0.726
# Epoch: 3/5... Step: 1600... Loss: 0.742145... Val Loss: 0.724724 Val Accuracy: 0.723
# Starting epoch 4
# Epoch: 4/5... Step: 100... Loss: 0.650193... Val Loss: 0.746671 Val Accuracy: 0.720
# Epoch: 4/5... Step: 200... Loss: 0.655519... Val Loss: 0.755061 Val Accuracy: 0.718
# Epoch: 4/5... Step: 300... Loss: 0.747141... Val Loss: 0.749752 Val Accuracy: 0.720
# Epoch: 4/5... Step: 400... Loss: 0.694544... Val Loss: 0.752959 Val Accuracy: 0.721
# Epoch: 4/5... Step: 500... Loss: 0.707131... Val Loss: 0.753137 Val Accuracy: 0.719
# Epoch: 4/5... Step: 600... Loss: 0.650232... Val Loss: 0.751486 Val Accuracy: 0.719
# Epoch: 4/5... Step: 700... Loss: 0.683426... Val Loss: 0.752015 Val Accuracy: 0.718
# Epoch: 4/5... Step: 800... Loss: 0.675501... Val Loss: 0.752550 Val Accuracy: 0.717
# Epoch: 4/5... Step: 900... Loss: 0.685372... Val Loss: 0.752642 Val Accuracy: 0.721
# Epoch: 4/5... Step: 1000... Loss: 0.697462... Val Loss: 0.752494 Val Accuracy: 0.721
# Epoch: 4/5... Step: 1100... Loss: 0.684113... Val Loss: 0.746118 Val Accuracy: 0.721
# Epoch: 4/5... Step: 1200... Loss: 0.680804... Val Loss: 0.743902 Val Accuracy: 0.720
# Epoch: 4/5... Step: 1300... Loss: 0.668594... Val Loss: 0.746898 Val Accuracy: 0.721
# Epoch: 4/5... Step: 1400... Loss: 0.711075... Val Loss: 0.747228 Val Accuracy: 0.718
# Epoch: 4/5... Step: 1500... Loss: 0.753482... Val Loss: 0.745765 Val Accuracy: 0.718
# Epoch: 4/5... Step: 1600... Loss: 0.743082... Val Loss: 0.744512 Val Accuracy: 0.719
# Starting epoch 5
# Epoch: 5/5... Step: 100... Loss: 0.628699... Val Loss: 0.794906 Val Accuracy: 0.716
# Epoch: 5/5... Step: 200... Loss: 0.629472... Val Loss: 0.796223 Val Accuracy: 0.714
# Epoch: 5/5... Step: 300... Loss: 0.611025... Val Loss: 0.802938 Val Accuracy: 0.714
# Epoch: 5/5... Step: 400... Loss: 0.611527... Val Loss: 0.799943 Val Accuracy: 0.713
# Epoch: 5/5... Step: 500... Loss: 0.650674... Val Loss: 0.793769 Val Accuracy: 0.712
# Epoch: 5/5... Step: 600... Loss: 0.651627... Val Loss: 0.797952 Val Accuracy: 0.716
# Epoch: 5/5... Step: 700... Loss: 0.630923... Val Loss: 0.791877 Val Accuracy: 0.714
# Epoch: 5/5... Step: 800... Loss: 0.713645... Val Loss: 0.794702 Val Accuracy: 0.714
# Epoch: 5/5... Step: 900... Loss: 0.648660... Val Loss: 0.790947 Val Accuracy: 0.714
# Epoch: 5/5... Step: 1000... Loss: 0.607441... Val Loss: 0.789485 Val Accuracy: 0.716
# Epoch: 5/5... Step: 1100... Loss: 0.574751... Val Loss: 0.794504 Val Accuracy: 0.716
# Epoch: 5/5... Step: 1200... Loss: 0.667301... Val Loss: 0.785560 Val Accuracy: 0.718
# Epoch: 5/5... Step: 1300... Loss: 0.642782... Val Loss: 0.789245 Val Accuracy: 0.716
# Epoch: 5/5... Step: 1400... Loss: 0.667685... Val Loss: 0.788838 Val Accuracy: 0.713
# Epoch: 5/5... Step: 1500... Loss: 0.719392... Val Loss: 0.784716 Val Accuracy: 0.715
# Epoch: 5/5... Step: 1600... Loss: 0.668870... Val Loss: 0.785004 Val Accuracy: 0.717

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [word for word in tokens if word in filtered_words]
    # Convert words to ids
    tokens = [vocab[word] for word in tokens]
        
    # Adding a batch dimension
    text_input = torch.tensor(tokens).unsqueeze(1)
    # Get the NN output
    hidden = model.init_hidden(text_input.size(1))
    logps, _ = model.forward(text_input,hidden)
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred.detach().numpy()

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# array([[  5.67783354e-05,   6.09978009e-03,   4.45301412e-03,
#           8.99497032e-01,   8.98933932e-02]], dtype=float32)

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
# ##ANSWER: The 3rd class is the prediction of the model with the accuracy of 89.9%, which is the uncertainty of 10.1%

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': array([[ 0.26453698,  0.22013088,  0.10143135,  0.18922345,  0.22467732]], dtype=float32),
#  'timestamp': '2018-11-01T00:00:18Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
